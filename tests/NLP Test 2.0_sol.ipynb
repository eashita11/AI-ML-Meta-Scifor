# %% [markdown]
# # STORY

# %% [markdown]
#  Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.

# %% [markdown]
# # Questions Using SpaCy, NLTK, and TextBlob
#
#
# 1- Tokenization
#
# Use NLTK to tokenize the text into words.
#
#
# Tokenize the text into sentences using spaCy.
#
#
# 2- Named Entity Recognition (NER)
#
# Use spaCy to extract all named entities in the text.
#
#
# Identify and count all locations mentioned in the text using spaCy's NER.
#
#
# 3- Part of Speech (POS) Tagging
#
# Use TextBlob to tag the parts of speech for each word.
#
# Extract and list all nouns in the text using spaCy.
#
#
# 4- Stop Words Removal
#
# Use NLTK to remove stop words from the text and display the cleaned text.
#
#
# Use spaCy to remove stop words, then join and display the text without stop words.
#
#
# 5- Lemmatization
#
# Use spaCy to lemmatize each word in the text.
#
#
# Use NLTK to lemmatize only the verbs in the text.
#
# 6- Sentiment Analysis
#
# Use TextBlob to perform sentiment analysis on the entire text.
#
#
# Divide the text into sentences and analyze the sentiment of each sentence with TextBlob.
#
#
# 7- N-Grams
#
# Generate bigrams (two-word combinations) using NLTK.
#
#
# Generate trigrams (three-word combinations) using TextBlob.
#
#
# 8- Frequency Distribution
#
# Use NLTK to compute the frequency distribution of words in the text.
#
# Find the 5 most common nouns in the text using spaCy.
#
#
# 9- Dependency Parsing
#
# Extract and display dependency parse information for each sentence using spaCy.
#
# Visualize the dependency tree of the first sentence using spaCy’s displacy tool.
#
#
# 10- Phrase Matching
#
# Identify occurrences of the phrase "Maratha Empire" using spaCy's PhraseMatcher.
#
#
# Use spaCy’s Matcher to find patterns where Shivaji Maharaj is mentioned along with actions (verbs).
#
#
# 11- Sentence Similarity
#
#
# Calculate the similarity between the first two sentences of the text using spaCy.
#
#
# Use TextBlob to compute the similarity between sentences mentioning "Shivaji" and "Mughal Empire."
#
#
# 12- Translation
#
#
# Translate the first paragraph into Hindi using TextBlob.
#
#
# Translate the phrase "Hindavi Swarajya" into French using TextBlob.
#
#
# 13- Keyword Extraction
#
#
# Extract keywords using NLTK’s frequency distribution (common nouns and verbs).
#
#
# Use spaCy to identify and list unique keywords from the text (filter out stop words).
#
#
# 14- Coreference Resolution
#
#
#
# Use spaCy's neuralcoref extension to resolve pronouns in the text.
#
#
# Identify any instances where pronouns can be replaced with entity names for better clarity.
#
#
# 15- Sentiment Polarity Distribution
#
# Calculate and plot the sentiment polarity distribution for each sentence in the text using TextBlob.
#
#
# Identify and display the most positive and most negative sentences based on sentiment scores.
#
#
# 16- Extract Dates and Events
#
#
# Identify all dates mentioned in the text using spaCy.
#
# Use regex to find sentences related to events happening in specific years (e.g., 1674 or 1680).
#
#
# 17- Synonyms and Antonyms
#
# Use TextBlob's WordNet to find synonyms for "bravery," "justice," and "valor."
#
#
# Find antonyms of "oppression" and "invasion" using NLTK’s WordNet.
#
#
# 18- Spelling Correction
#
# Introduce 5 spelling errors in the text and use TextBlob to correct them.
#
#
# Identify words with potential spelling errors using TextBlob.
#
#
# 19- Extract Subject-Verb-Object Triples
#
# Use spaCy to extract subject-verb-object triples from the sentences.
#
#
# Identify and list sentences where "Shivaji" is the subject and a verb follows, using dependency parsing.
#
# 20- Create a Summary
#
# Summarize the text using TextBlob by extracting key sentences.
#
#
# Generate a summary using NLTK’s summarize function on cleaned text.

# %% [markdown]
# # SOLUTIONS

# %% [markdown]
# ### 1- Tokenization
#
# Use NLTK to tokenize the text into words.
#
# Tokenize the text into sentences using spaCy.

# %%
from nltk.tokenize import word_tokenize
import nltk

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/anil/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text="Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture."

# %%
# Tokenize the text into words
word_tokens = word_tokenize(text)
print("Word Tokens:", word_tokens)
# Out:
# Word Tokens: ['Chhatrapati', 'Shivaji', 'Maharaj', 'was', 'born', 'on', 'February', '19', ',', '1630', ',', 'at', 'Shivneri', 'Fort', 'in', 'Maharashtra', ',', 'to', 'Shahaji', 'Bhonsle', ',', 'a', 'Maratha', 'general', ',', 'and', 'Jijabai', ',', 'who', 'deeply', 'influenced', 'Shivaji', 'with', 'her', 'teachings', 'on', 'dharma', ',', 'bravery', ',', 'and', 'justice', '.', 'From', 'an', 'early', 'age', ',', 'Shivaji', 'exhibited', 'remarkable', 'leadership', 'qualities', ',', 'forming', 'a', 'group', 'of', 'loyal', 'followers', 'and', 'honing', 'his', 'military', 'skills', 'in', 'the', 'rugged', 'terrain', 'of', 'the', 'Sahyadri', 'mountains', '.', 'He', 'grew', 'up', 'during', 'a', 'time', 'when', 'the', 'Mughal', 'Empire', 'under', 'Emperor', 'Aurangzeb', 'and', 'the', 'Deccan', 'Sultanates', 'were', 'vying', 'for', 'control', ',', 'often', 'oppressing', 'the', 'local', 'population', ',', 'which', 'deeply', 'disturbed', 'him', 'and', 'fueled', 'his', 'desire', 'to', 'establish', 'Swarajya', ',', 'or', 'self-rule', 'for', 'the', 'Marathas', '.', 'By', 'the', 'age', 'of', '16', ',', 'Shivaji', 'had', 'captured', 'his', 'first', 'fort', ',', 'Torna', ',', 'using', 'guerrilla', 'warfare', 'tactics', 'that', 'would', 'later', 'become', 'a', 'hallmark', 'of', 'his', 'military', 'strategy', '.', 'As', 'his', 'conquests', 'grew', ',', 'he', 'formed', 'alliances', 'with', 'local', 'leaders', ',', 'securing', 'key', 'forts', 'like', 'Raigad', ',', 'Kondana', ',', 'and', 'Purandar', ',', 'establishing', 'a', 'solid', 'territorial', 'base', 'in', 'western', 'India', '.', 'In', '1659', ',', 'he', 'faced', 'and', 'defeated', 'Afzal', 'Khan', ',', 'a', 'prominent', 'general', 'of', 'the', 'Bijapur', 'Sultanate', ',', 'solidifying', 'his', 'reputation', 'as', 'a', 'brave', 'and', 'tactical', 'leader', ';', 'this', 'victory', 'was', 'crucial', 'in', 'establishing', 'his', 'control', 'over', 'much', 'of', 'the', 'Deccan', '.', 'Shivaji', '’', 's', 'raids', 'on', 'Mughal', 'territories', 'and', 'his', 'escape', 'from', 'the', 'clutches', 'of', 'Aurangzeb', 'in', 'Agra', 'in', '1666', 'further', 'bolstered', 'his', 'legend', '.', 'He', 'realized', 'that', 'a', 'powerful', 'navy', 'was', 'crucial', 'to', 'safeguard', 'his', 'territories', 'from', 'foreign', 'invasions', ',', 'leading', 'him', 'to', 'develop', 'one', 'of', 'the', 'earliest', 'organized', 'naval', 'forces', 'in', 'India', ',', 'allowing', 'him', 'to', 'secure', 'coastal', 'areas', 'against', 'Portuguese', ',', 'British', ',', 'and', 'Siddis', 'forces', '.', 'In', '1674', ',', 'he', 'formally', 'crowned', 'himself', 'as', 'Chhatrapati', 'at', 'Raigad', 'Fort', ',', 'declaring', 'his', 'independence', 'and', 'establishing', 'the', 'Maratha', 'Empire', ',', 'thus', 'becoming', 'the', 'first', 'king', 'to', 'establish', 'Hindavi', 'Swarajya', ',', 'an', 'autonomous', 'kingdom', 'with', 'a', 'structured', 'administrative', 'framework', 'rooted', 'in', 'Indian', 'ethos', '.', 'Shivaji', '’', 's', 'administrative', 'system', 'was', 'highly', 'efficient', ',', 'and', 'he', 'emphasized', 'the', 'welfare', 'of', 'his', 'people', ',', 'setting', 'up', 'systems', 'to', 'reduce', 'corruption', 'and', 'create', 'a', 'fair', 'tax', 'structure', ';', 'his', 'Ashta', 'Pradhan', '(', 'Council', 'of', 'Eight', 'Ministers', ')', 'included', 'departments', 'for', 'finance', ',', 'internal', 'affairs', ',', 'foreign', 'policy', ',', 'and', 'military', 'to', 'ensure', 'smooth', 'governance', '.', 'Shivaji', 'showed', 'a', 'progressive', 'approach', 'towards', 'governance', ',', 'promoting', 'religious', 'tolerance', 'and', 'respecting', 'the', 'diversity', 'within', 'his', 'empire', ',', 'even', 'appointing', 'Muslims', 'to', 'key', 'positions', 'in', 'his', 'administration', 'and', 'banning', 'the', 'harassment', 'of', 'women', 'and', 'looting', 'of', 'religious', 'sites', '.', 'His', 'respect', 'for', 'women', 'and', 'his', 'advocacy', 'for', 'justice', 'inspired', 'trust', 'and', 'loyalty', 'among' ...

# %%
# Tokenizing words into sentences using spaCy
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Tokenize into sentences
doc = nlp(text)
sentence_tokens = [sent.text for sent in doc.sents]
print("Sentence Tokens:", sentence_tokens)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/anil/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/anil/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/anil/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/90/32_msyv95d93xhhstk2p072c0000gn/T/ipykernel_33673/266465427.py", line 2, in <module>
#     import spacy
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/spacy/__init__.py", line 6, in <module>
#     from .errors import setup_default_warnings
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/spacy/errors.py", line 3, in <module>
#     from .compat import Literal
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/spacy/compat.py", line 4, in <module>
#     from thinc.util import copy_array
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/thinc/__init__.py", line 5, in <module>
#     from .config import registry
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/thinc/config.py", line 5, in <module>
#     from .types import Decorator
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/thinc/types.py", line 25, in <module>
#     from .compat import cupy, has_cupy
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/thinc/compat.py", line 35, in <module>
#     import torch
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/torch/__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/Users/anil/anaconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/anil/anaconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# Sentence Tokens: ['Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice.', 'From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.', 'He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas.', 'By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy.', 'As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.', 'In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan.', 'Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend.', 'He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces.', 'In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.', 'Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance.', 'Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites.', 'His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time.', 'Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses.', 'As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India.', 'Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.', 'His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.']

# %% [markdown]
# ## 2- Named Entity Recognition (NER)
#
# Use spaCy to extract all named entities in the text.
#
# Identify and count all locations mentioned in the text using spaCy's NER.

# %%
import spacy

# Load spaCy's English model for NER
nlp = spacy.load("en_core_web_sm")

# Perform NER
doc = nlp(text)
entities = [(ent.text, ent.label_) for ent in doc.ents]

# Display all entities
print("All Named Entities:", entities)

# Filter and count location entities
locations = [ent.text for ent in doc.ents if ent.label_ == "GPE"]  # "GPE" stands for Geopolitical Entity
location_count = len(locations)
print("Locations:", locations)
print("Number of Locations:", location_count)
# Out:
# All Named Entities: [('Chhatrapati Shivaji Maharaj', 'PERSON'), ('February 19, 1630', 'DATE'), ('Shivneri Fort', 'FAC'), ('Maharashtra', 'LOC'), ('Shahaji Bhonsle', 'PERSON'), ('Maratha', 'GPE'), ('Jijabai', 'GPE'), ('Shivaji', 'PERSON'), ('an early age', 'DATE'), ('Shivaji', 'PERSON'), ('Sahyadri', 'LOC'), ('the Mughal Empire', 'ORG'), ('Emperor Aurangzeb', 'ORG'), ('Swarajya', 'ORG'), ('Marathas', 'GPE'), ('the age of 16', 'DATE'), ('Shivaji', 'PERSON'), ('first', 'ORDINAL'), ('Torna', 'GPE'), ('Raigad', 'GPE'), ('Kondana', 'PERSON'), ('Purandar', 'PERSON'), ('India', 'GPE'), ('1659', 'DATE'), ('Afzal Khan', 'PERSON'), ('Deccan', 'NORP'), ('Aurangzeb', 'GPE'), ('Agra', 'GPE'), ('1666', 'DATE'), ('navy', 'ORG'), ('one', 'CARDINAL'), ('India', 'GPE'), ('Portuguese', 'NORP'), ('British', 'NORP'), ('Siddis', 'PERSON'), ('1674', 'DATE'), ('Chhatrapati', 'ORG'), ('Raigad Fort', 'FAC'), ('the Maratha Empire', 'LOC'), ('first', 'ORDINAL'), ('Hindavi Swarajya', 'PERSON'), ('Indian', 'NORP'), ('Ashta Pradhan (Council', 'ORG'), ('Muslims', 'NORP'), ('Shivaji Maharaj’s', 'PERSON'), ('Ganimi Kava', 'PERSON'), ('the Maratha Empire', 'ORG'), ('Maharashtra', 'ORG'), ('Maratha', 'PERSON'), ('India', 'GPE'), ('April 3, 1680', 'DATE'), ('Raigad Fort', 'FAC'), ('millions', 'CARDINAL'), ('the Maratha Empire’s', 'ORG'), ('India', 'GPE')]
# Locations: ['Maratha', 'Jijabai', 'Marathas', 'Torna', 'Raigad', 'India', 'Aurangzeb', 'Agra', 'India', 'India', 'India']
# Number of Locations: 11

# %% [markdown]
# ## 3- Part of Speech (POS) Tagging
#
# Use TextBlob to tag the parts of speech for each word.
#
# Extract and list all nouns in the text using spaCy.

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /Users/anil/anaconda3/lib/python3.11/site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in /Users/anil/.local/lib/python3.11/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /Users/anil/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (8.0.4)
# Requirement already satisfied: joblib in /Users/anil/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/anil/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/anil/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (4.65.0)

# %%
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to /Users/anil/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/anil/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/anil/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/anil/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /Users/anil/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/anil/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.

# %%
from textblob import TextBlob

# Create a TextBlob object
blob = TextBlob(text)

# Perform POS tagging
pos_tags = blob.tags
print("POS Tags:", pos_tags)
# Out:
# POS Tags: [('Chhatrapati', 'NNP'), ('Shivaji', 'NNP'), ('Maharaj', 'NNP'), ('was', 'VBD'), ('born', 'VBN'), ('on', 'IN'), ('February', 'NNP'), ('19', 'CD'), ('1630', 'CD'), ('at', 'IN'), ('Shivneri', 'NNP'), ('Fort', 'NNP'), ('in', 'IN'), ('Maharashtra', 'NNP'), ('to', 'TO'), ('Shahaji', 'NNP'), ('Bhonsle', 'NNP'), ('a', 'DT'), ('Maratha', 'NNP'), ('general', 'NN'), ('and', 'CC'), ('Jijabai', 'NNP'), ('who', 'WP'), ('deeply', 'RB'), ('influenced', 'VBD'), ('Shivaji', 'NNP'), ('with', 'IN'), ('her', 'PRP$'), ('teachings', 'NNS'), ('on', 'IN'), ('dharma', 'NN'), ('bravery', 'NN'), ('and', 'CC'), ('justice', 'NN'), ('From', 'IN'), ('an', 'DT'), ('early', 'JJ'), ('age', 'NN'), ('Shivaji', 'NNP'), ('exhibited', 'VBD'), ('remarkable', 'JJ'), ('leadership', 'NN'), ('qualities', 'NNS'), ('forming', 'VBG'), ('a', 'DT'), ('group', 'NN'), ('of', 'IN'), ('loyal', 'JJ'), ('followers', 'NNS'), ('and', 'CC'), ('honing', 'VBG'), ('his', 'PRP$'), ('military', 'JJ'), ('skills', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('rugged', 'JJ'), ('terrain', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Sahyadri', 'NNP'), ('mountains', 'NNS'), ('He', 'PRP'), ('grew', 'VBD'), ('up', 'RP'), ('during', 'IN'), ('a', 'DT'), ('time', 'NN'), ('when', 'WRB'), ('the', 'DT'), ('Mughal', 'NNP'), ('Empire', 'NNP'), ('under', 'IN'), ('Emperor', 'NNP'), ('Aurangzeb', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('Deccan', 'NNP'), ('Sultanates', 'NNPS'), ('were', 'VBD'), ('vying', 'VBG'), ('for', 'IN'), ('control', 'NN'), ('often', 'RB'), ('oppressing', 'VBG'), ('the', 'DT'), ('local', 'JJ'), ('population', 'NN'), ('which', 'WDT'), ('deeply', 'RB'), ('disturbed', 'VBD'), ('him', 'PRP'), ('and', 'CC'), ('fueled', 'VBD'), ('his', 'PRP$'), ('desire', 'NN'), ('to', 'TO'), ('establish', 'VB'), ('Swarajya', 'NNP'), ('or', 'CC'), ('self-rule', 'NN'), ('for', 'IN'), ('the', 'DT'), ('Marathas', 'NNP'), ('By', 'IN'), ('the', 'DT'), ('age', 'NN'), ('of', 'IN'), ('16', 'CD'), ('Shivaji', 'NNP'), ('had', 'VBD'), ('captured', 'VBN'), ('his', 'PRP$'), ('first', 'JJ'), ('fort', 'NN'), ('Torna', 'NNP'), ('using', 'VBG'), ('guerrilla', 'NN'), ('warfare', 'NN'), ('tactics', 'NNS'), ('that', 'WDT'), ('would', 'MD'), ('later', 'RB'), ('become', 'VB'), ('a', 'DT'), ('hallmark', 'NN'), ('of', 'IN'), ('his', 'PRP$'), ('military', 'JJ'), ('strategy', 'NN'), ('As', 'IN'), ('his', 'PRP$'), ('conquests', 'NNS'), ('grew', 'VBD'), ('he', 'PRP'), ('formed', 'VBD'), ('alliances', 'NNS'), ('with', 'IN'), ('local', 'JJ'), ('leaders', 'NNS'), ('securing', 'VBG'), ('key', 'JJ'), ('forts', 'NNS'), ('like', 'IN'), ('Raigad', 'NNP'), ('Kondana', 'NNP'), ('and', 'CC'), ('Purandar', 'NNP'), ('establishing', 'VBG'), ('a', 'DT'), ('solid', 'JJ'), ('territorial', 'JJ'), ('base', 'NN'), ('in', 'IN'), ('western', 'JJ'), ('India', 'NNP'), ('In', 'IN'), ('1659', 'CD'), ('he', 'PRP'), ('faced', 'VBD'), ('and', 'CC'), ('defeated', 'VBD'), ('Afzal', 'NNP'), ('Khan', 'NNP'), ('a', 'DT'), ('prominent', 'JJ'), ('general', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Bijapur', 'NNP'), ('Sultanate', 'NNP'), ('solidifying', 'VBG'), ('his', 'PRP$'), ('reputation', 'NN'), ('as', 'IN'), ('a', 'DT'), ('brave', 'NN'), ('and', 'CC'), ('tactical', 'JJ'), ('leader', 'NN'), ('this', 'DT'), ('victory', 'NN'), ('was', 'VBD'), ('crucial', 'JJ'), ('in', 'IN'), ('establishing', 'VBG'), ('his', 'PRP$'), ('control', 'NN'), ('over', 'IN'), ('much', 'JJ'), ('of', 'IN'), ('the', 'DT'), ('Deccan', 'NNP'), ('Shivaji', 'NNP'), ('’', 'NNP'), ('s', 'JJ'), ('raids', 'NNS'), ('on', 'IN'), ('Mughal', 'NNP'), ('territories', 'NNS'), ('and', 'CC'), ('his', 'PRP$'), ('escape', 'NN'), ('from', 'IN'), ('the', 'DT'), ('clutches', 'NNS'), ('of', 'IN'), ('Aurangzeb', 'NNP'), ('in', 'IN'), ('Agra', 'NNP'), ('in', 'IN'), ('1666', 'CD'), ('further', 'RB'), ('bolstered', 'VBD'), ('his', 'PRP$'), ('legend', 'NN'), ('He', 'PRP'), ('realized', 'VBD'), ('that', 'IN'), ('a', 'DT'), ('powerful', 'JJ'), ('navy', 'NN'), ('was', 'VBD'), ('crucial', 'JJ'), ('to', 'TO'), ('safeguard', 'VB'), ('his',  ...

# %%
# Extracting and listing all nouns 
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Process the text
doc = nlp(text)

# Extract and list all nouns
nouns = [token.text for token in doc if token.pos_ == "NOUN"]
print("Nouns:", nouns)
# Out:
# Nouns: ['general', 'teachings', 'dharma', 'bravery', 'justice', 'age', 'leadership', 'qualities', 'group', 'followers', 'skills', 'terrain', 'mountains', 'time', 'control', 'population', 'desire', 'self', 'rule', 'age', 'fort', 'guerrilla', 'warfare', 'tactics', 'hallmark', 'strategy', 'conquests', 'alliances', 'leaders', 'forts', 'base', 'general', 'reputation', 'leader', 'victory', 'control', 'raids', 'territories', 'escape', 'clutches', 'legend', 'navy', 'territories', 'invasions', 'forces', 'areas', 'forces', 'independence', 'king', 'kingdom', 'framework', 'ethos', 'system', 'welfare', 'people', 'systems', 'corruption', 'tax', 'structure', 'departments', 'finance', 'affairs', 'policy', 'military', 'governance', 'approach', 'governance', 'tolerance', 'diversity', 'empire', 'positions', 'administration', 'harassment', 'women', 'looting', 'sites', 'respect', 'women', 'advocacy', 'justice', 'trust', 'loyalty', 'people', 'ruler', 'time', 'guerrilla', 'tactics', 'armies', 'empire', 'losses', 'fame', 'regions', 'forces', 'power', 'legacy', 'state', 'death', 'life', 'ideals', 'valor', 'respect', 'faiths', 'self', 'rule', 'millions', 'legacy', 'form', 'contributions', 'history', 'culture']

# %% [markdown]
# ## 4- Stop Words Removal
#
# Use NLTK to remove stop words from the text and display the cleaned text.
#
# Use spaCy to remove stop words, then join and display the text without stop words.

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/anil/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Tokenize and remove stop words
stop_words = set(stopwords.words('english'))
words = word_tokenize(text)
filtered_text_nltk = [word for word in words if word.lower() not in stop_words]
print("Text after Stop Words Removal (NLTK):", " ".join(filtered_text_nltk))
# Out:
# Text after Stop Words Removal (NLTK): Chhatrapati Shivaji Maharaj born February 19 , 1630 , Shivneri Fort Maharashtra , Shahaji Bhonsle , Maratha general , Jijabai , deeply influenced Shivaji teachings dharma , bravery , justice . early age , Shivaji exhibited remarkable leadership qualities , forming group loyal followers honing military skills rugged terrain Sahyadri mountains . grew time Mughal Empire Emperor Aurangzeb Deccan Sultanates vying control , often oppressing local population , deeply disturbed fueled desire establish Swarajya , self-rule Marathas . age 16 , Shivaji captured first fort , Torna , using guerrilla warfare tactics would later become hallmark military strategy . conquests grew , formed alliances local leaders , securing key forts like Raigad , Kondana , Purandar , establishing solid territorial base western India . 1659 , faced defeated Afzal Khan , prominent general Bijapur Sultanate , solidifying reputation brave tactical leader ; victory crucial establishing control much Deccan . Shivaji ’ raids Mughal territories escape clutches Aurangzeb Agra 1666 bolstered legend . realized powerful navy crucial safeguard territories foreign invasions , leading develop one earliest organized naval forces India , allowing secure coastal areas Portuguese , British , Siddis forces . 1674 , formally crowned Chhatrapati Raigad Fort , declaring independence establishing Maratha Empire , thus becoming first king establish Hindavi Swarajya , autonomous kingdom structured administrative framework rooted Indian ethos . Shivaji ’ administrative system highly efficient , emphasized welfare people , setting systems reduce corruption create fair tax structure ; Ashta Pradhan ( Council Eight Ministers ) included departments finance , internal affairs , foreign policy , military ensure smooth governance . Shivaji showed progressive approach towards governance , promoting religious tolerance respecting diversity within empire , even appointing Muslims key positions administration banning harassment women looting religious sites . respect women advocacy justice inspired trust loyalty among people , making ideal ruler time . Shivaji Maharaj ’ guerrilla tactics , known “ Ganimi Kava , ” became legendary enabled outmaneuver much larger better-equipped armies repeatedly , allowing expand empire minimizing losses . fame grew , Maratha Empire began influence regions far beyond Maharashtra , Maratha forces eventually becoming significant power across India . Shivaji passed away April 3 , 1680 , Raigad Fort , leaving behind powerful legacy well-organized state continued expand death . life ideals—valor , respect faiths , self-rule—continue inspire millions , legacy endures form Maratha Empire ’ contributions India ’ history culture .

# %%
# Stop Words Removal with spaCy
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Process the text
doc = nlp(text)

# Remove stop words and join the remaining words
filtered_text_spacy = [token.text for token in doc if not token.is_stop]
print("Text after Stop Words Removal (spaCy):", " ".join(filtered_text_spacy))
# Out:
# Text after Stop Words Removal (spaCy): Chhatrapati Shivaji Maharaj born February 19 , 1630 , Shivneri Fort Maharashtra , Shahaji Bhonsle , Maratha general , Jijabai , deeply influenced Shivaji teachings dharma , bravery , justice . early age , Shivaji exhibited remarkable leadership qualities , forming group loyal followers honing military skills rugged terrain Sahyadri mountains . grew time Mughal Empire Emperor Aurangzeb Deccan Sultanates vying control , oppressing local population , deeply disturbed fueled desire establish Swarajya , self - rule Marathas . age 16 , Shivaji captured fort , Torna , guerrilla warfare tactics later hallmark military strategy . conquests grew , formed alliances local leaders , securing key forts like Raigad , Kondana , Purandar , establishing solid territorial base western India . 1659 , faced defeated Afzal Khan , prominent general Bijapur Sultanate , solidifying reputation brave tactical leader ; victory crucial establishing control Deccan . Shivaji raids Mughal territories escape clutches Aurangzeb Agra 1666 bolstered legend . realized powerful navy crucial safeguard territories foreign invasions , leading develop earliest organized naval forces India , allowing secure coastal areas Portuguese , British , Siddis forces . 1674 , formally crowned Chhatrapati Raigad Fort , declaring independence establishing Maratha Empire , king establish Hindavi Swarajya , autonomous kingdom structured administrative framework rooted Indian ethos . Shivaji administrative system highly efficient , emphasized welfare people , setting systems reduce corruption create fair tax structure ; Ashta Pradhan ( Council Ministers ) included departments finance , internal affairs , foreign policy , military ensure smooth governance . Shivaji showed progressive approach governance , promoting religious tolerance respecting diversity empire , appointing Muslims key positions administration banning harassment women looting religious sites . respect women advocacy justice inspired trust loyalty people , making ideal ruler time . Shivaji Maharaj guerrilla tactics , known “ Ganimi Kava , ” legendary enabled outmaneuver larger better - equipped armies repeatedly , allowing expand empire minimizing losses . fame grew , Maratha Empire began influence regions far Maharashtra , Maratha forces eventually significant power India . Shivaji passed away April 3 , 1680 , Raigad Fort , leaving powerful legacy - organized state continued expand death . life ideals — valor , respect faiths , self - rule — continue inspire millions , legacy endures form Maratha Empire contributions India history culture .

# %% [markdown]
# ## 5- Lemmatization
#
# Use spaCy to lemmatize each word in the text.
#
# Use NLTK to lemmatize only the verbs in the text.

# %%
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Perform lemmatization on all words
doc = nlp(text)
lemmatized_text_spacy = [token.lemma_ for token in doc]
print("Lemmatized Text (spaCy):", " ".join(lemmatized_text_spacy))
# Out:
# Lemmatized Text (spaCy): Chhatrapati Shivaji Maharaj be bear on February 19 , 1630 , at Shivneri Fort in Maharashtra , to Shahaji Bhonsle , a Maratha general , and Jijabai , who deeply influence Shivaji with her teaching on dharma , bravery , and justice . from an early age , Shivaji exhibit remarkable leadership quality , form a group of loyal follower and hone his military skill in the rugged terrain of the Sahyadri mountain . he grow up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates be vie for control , often oppress the local population , which deeply disturb he and fuel his desire to establish Swarajya , or self - rule for the Marathas . by the age of 16 , Shivaji have capture his first fort , Torna , use guerrilla warfare tactic that would later become a hallmark of his military strategy . as his conquest grow , he form alliance with local leader , secure key fort like Raigad , Kondana , and Purandar , establish a solid territorial base in western India . in 1659 , he face and defeat Afzal Khan , a prominent general of the Bijapur Sultanate , solidify his reputation as a brave and tactical leader ; this victory be crucial in establish his control over much of the Deccan . Shivaji ’s raid on Mughal territory and his escape from the clutch of Aurangzeb in Agra in 1666 far bolster his legend . he realize that a powerful navy be crucial to safeguard his territory from foreign invasion , lead he to develop one of the early organize naval force in India , allow he to secure coastal area against portuguese , british , and Siddis force . in 1674 , he formally crown himself as Chhatrapati at Raigad Fort , declare his independence and establish the Maratha Empire , thus become the first king to establish Hindavi Swarajya , an autonomous kingdom with a structured administrative framework root in indian ethos . Shivaji ’s administrative system be highly efficient , and he emphasize the welfare of his people , set up system to reduce corruption and create a fair tax structure ; his Ashta Pradhan ( Council of Eight Ministers ) include department for finance , internal affair , foreign policy , and military to ensure smooth governance . Shivaji show a progressive approach towards governance , promote religious tolerance and respect the diversity within his empire , even appoint Muslims to key position in his administration and ban the harassment of woman and looting of religious site . his respect for woman and his advocacy for justice inspire trust and loyalty among his people , make he an ideal ruler for his time . Shivaji Maharaj ’s guerrilla tactic , know as " Ganimi Kava , " become legendary and enable he to outmaneuver much large and well - equip army repeatedly , allow he to expand his empire while minimize loss . as his fame grow , the Maratha Empire begin to influence region far beyond Maharashtra , with Maratha force eventually become a significant power across India . Shivaji pass away on April 3 , 1680 , at Raigad Fort , leave behind a powerful legacy and a well - organize state that continue to expand after his death . his life and ideal — valor , respect for all faith , and self - rule — continue to inspire million , and his legacy endure in the form of the Maratha Empire ’s contribution to India ’s history and culture .

# %%
# Lemmatization of Verbs Only with NLTK
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize
import nltk

nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/anil/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /Users/anil/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/anil/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to convert NLTK POS tags to WordNet POS tags
def get_wordnet_pos(tag):
    if tag.startswith('V'):
        return wordnet.VERB
    return None

# Tokenize, tag, and lemmatize verbs only
words = word_tokenize(text)
pos_tags = pos_tag(words)
lemmatized_verbs_nltk = [lemmatizer.lemmatize(word, get_wordnet_pos(tag)) if get_wordnet_pos(tag) else word for word, tag in pos_tags]
print("Lemmatized Verbs Only (NLTK):", " ".join(lemmatized_verbs_nltk))
# Out:
# Lemmatized Verbs Only (NLTK): Chhatrapati Shivaji Maharaj be bear on February 19 , 1630 , at Shivneri Fort in Maharashtra , to Shahaji Bhonsle , a Maratha general , and Jijabai , who deeply influence Shivaji with her teachings on dharma , bravery , and justice . From an early age , Shivaji exhibit remarkable leadership qualities , form a group of loyal followers and hone his military skills in the rugged terrain of the Sahyadri mountains . He grow up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates be vie for control , often oppress the local population , which deeply disturb him and fuel his desire to establish Swarajya , or self-rule for the Marathas . By the age of 16 , Shivaji have capture his first fort , Torna , use guerrilla warfare tactics that would later become a hallmark of his military strategy . As his conquests grow , he form alliances with local leaders , secure key forts like Raigad , Kondana , and Purandar , establish a solid territorial base in western India . In 1659 , he face and defeat Afzal Khan , a prominent general of the Bijapur Sultanate , solidify his reputation as a brave and tactical leader ; this victory be crucial in establish his control over much of the Deccan . Shivaji ’ s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolster his legend . He realize that a powerful navy be crucial to safeguard his territories from foreign invasions , lead him to develop one of the earliest organize naval forces in India , allow him to secure coastal areas against Portuguese , British , and Siddis forces . In 1674 , he formally crown himself as Chhatrapati at Raigad Fort , declare his independence and establish the Maratha Empire , thus become the first king to establish Hindavi Swarajya , an autonomous kingdom with a structured administrative framework root in Indian ethos . Shivaji ’ s administrative system be highly efficient , and he emphasize the welfare of his people , set up systems to reduce corruption and create a fair tax structure ; his Ashta Pradhan ( Council of Eight Ministers ) include departments for finance , internal affairs , foreign policy , and military to ensure smooth governance . Shivaji show a progressive approach towards governance , promote religious tolerance and respect the diversity within his empire , even appoint Muslims to key positions in his administration and ban the harassment of women and looting of religious sites . His respect for women and his advocacy for justice inspire trust and loyalty among his people , make him an ideal ruler for his time . Shivaji Maharaj ’ s guerrilla tactics , know as “ Ganimi Kava , ” become legendary and enable him to outmaneuver much larger and better-equipped armies repeatedly , allow him to expand his empire while minimize losses . As his fame grow , the Maratha Empire begin to influence regions far beyond Maharashtra , with Maratha forces eventually become a significant power across India . Shivaji pass away on April 3 , 1680 , at Raigad Fort , leave behind a powerful legacy and a well-organized state that continue to expand after his death . His life and ideals—valor , respect for all faiths , and self-rule—continue to inspire millions , and his legacy endure in the form of the Maratha Empire ’ s contributions to India ’ s history and culture .

# %% [markdown]
# ## 6- Sentiment Analysis
#
# Use TextBlob to perform sentiment analysis on the entire text.
#
# Divide the text into sentences and analyze the sentiment of each sentence with TextBlob.

# %%
# Create a TextBlob object
blob = TextBlob(text)

# Perform sentiment analysis on the entire text
sentiment = blob.sentiment
print("Sentiment of Entire Text:", sentiment)
# Out:
# Sentiment of Entire Text: Sentiment(polarity=0.15890070921985816, subjectivity=0.5364893617021277)

# %%
# Analyze sentiment of each sentence
for sentence in blob.sentences:
    print(f"Sentence: {sentence}")
    print("Sentiment:", sentence.sentiment)
# Out:
# Sentence: Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice.
# Sentiment: Sentiment(polarity=0.02500000000000001, subjectivity=0.45)
# Sentence: From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.
# Sentiment: Sentiment(polarity=0.2708333333333333, subjectivity=0.49583333333333335)
# Sentence: He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas.
# Sentiment: Sentiment(polarity=0.0, subjectivity=0.2)
# Sentence: By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy.
# Sentiment: Sentiment(polarity=0.049999999999999996, subjectivity=0.14444444444444446)
# Sentence: As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.
# Sentiment: Sentiment(polarity=-0.16, subjectivity=0.42000000000000004)
# Sentence: In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan.
# Sentiment: Sentiment(polarity=0.31, subjectivity=0.74)
# Sentence: Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend.
# Sentiment: Sentiment(polarity=0.0, subjectivity=0.5)
# Sentence: He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces.
# Sentiment: Sentiment(polarity=0.11499999999999999, subjectivity=0.545)
# Sentence: In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.
# Sentiment: Sentiment(polarity=0.3666666666666667, subjectivity=0.6277777777777778)
# Sentence: Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance.
# Sentiment: Sentiment(polarity=0.17250000000000001, subjectivity=0.36083333333333334)
# Sentence: Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites.
# Sentiment: Sentiment(polarity=0.0, subjectivity=0.5)
# Sentence: His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time.
# Sentiment: Sentiment(polarity=0.9, subjectivity=1.0)
# Sentence: Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses.
# Sentiment: Sentiment(polarity=0.5, subjectivity=0.75)
# Sentence: As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India.
# Sentiment: Sentiment(polarity=0.30833333333333335, subjectivity=0.9083333333333333)
# Sentence: Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.
# Sentiment: Sentiment(polarity=-0.05000000000000002, subjectivity=0.85)
# Sentence: His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.
# Sentiment: Sentiment(polarity=0.0, subjectivity=0.0)

# %% [markdown]
# ## 7- N-Grams
#
# Generate bigrams (two-word combinations) using NLTK.
#
# Generate trigrams (three-word combinations) using TextBlob.

# %%
from nltk import bigrams, word_tokenize

# Tokenize and generate bigrams
tokens = word_tokenize(text)
bigrams_list = list(bigrams(tokens))
print("Bigrams:", bigrams_list)
# Out:
# Bigrams: [('Chhatrapati', 'Shivaji'), ('Shivaji', 'Maharaj'), ('Maharaj', 'was'), ('was', 'born'), ('born', 'on'), ('on', 'February'), ('February', '19'), ('19', ','), (',', '1630'), ('1630', ','), (',', 'at'), ('at', 'Shivneri'), ('Shivneri', 'Fort'), ('Fort', 'in'), ('in', 'Maharashtra'), ('Maharashtra', ','), (',', 'to'), ('to', 'Shahaji'), ('Shahaji', 'Bhonsle'), ('Bhonsle', ','), (',', 'a'), ('a', 'Maratha'), ('Maratha', 'general'), ('general', ','), (',', 'and'), ('and', 'Jijabai'), ('Jijabai', ','), (',', 'who'), ('who', 'deeply'), ('deeply', 'influenced'), ('influenced', 'Shivaji'), ('Shivaji', 'with'), ('with', 'her'), ('her', 'teachings'), ('teachings', 'on'), ('on', 'dharma'), ('dharma', ','), (',', 'bravery'), ('bravery', ','), (',', 'and'), ('and', 'justice'), ('justice', '.'), ('.', 'From'), ('From', 'an'), ('an', 'early'), ('early', 'age'), ('age', ','), (',', 'Shivaji'), ('Shivaji', 'exhibited'), ('exhibited', 'remarkable'), ('remarkable', 'leadership'), ('leadership', 'qualities'), ('qualities', ','), (',', 'forming'), ('forming', 'a'), ('a', 'group'), ('group', 'of'), ('of', 'loyal'), ('loyal', 'followers'), ('followers', 'and'), ('and', 'honing'), ('honing', 'his'), ('his', 'military'), ('military', 'skills'), ('skills', 'in'), ('in', 'the'), ('the', 'rugged'), ('rugged', 'terrain'), ('terrain', 'of'), ('of', 'the'), ('the', 'Sahyadri'), ('Sahyadri', 'mountains'), ('mountains', '.'), ('.', 'He'), ('He', 'grew'), ('grew', 'up'), ('up', 'during'), ('during', 'a'), ('a', 'time'), ('time', 'when'), ('when', 'the'), ('the', 'Mughal'), ('Mughal', 'Empire'), ('Empire', 'under'), ('under', 'Emperor'), ('Emperor', 'Aurangzeb'), ('Aurangzeb', 'and'), ('and', 'the'), ('the', 'Deccan'), ('Deccan', 'Sultanates'), ('Sultanates', 'were'), ('were', 'vying'), ('vying', 'for'), ('for', 'control'), ('control', ','), (',', 'often'), ('often', 'oppressing'), ('oppressing', 'the'), ('the', 'local'), ('local', 'population'), ('population', ','), (',', 'which'), ('which', 'deeply'), ('deeply', 'disturbed'), ('disturbed', 'him'), ('him', 'and'), ('and', 'fueled'), ('fueled', 'his'), ('his', 'desire'), ('desire', 'to'), ('to', 'establish'), ('establish', 'Swarajya'), ('Swarajya', ','), (',', 'or'), ('or', 'self-rule'), ('self-rule', 'for'), ('for', 'the'), ('the', 'Marathas'), ('Marathas', '.'), ('.', 'By'), ('By', 'the'), ('the', 'age'), ('age', 'of'), ('of', '16'), ('16', ','), (',', 'Shivaji'), ('Shivaji', 'had'), ('had', 'captured'), ('captured', 'his'), ('his', 'first'), ('first', 'fort'), ('fort', ','), (',', 'Torna'), ('Torna', ','), (',', 'using'), ('using', 'guerrilla'), ('guerrilla', 'warfare'), ('warfare', 'tactics'), ('tactics', 'that'), ('that', 'would'), ('would', 'later'), ('later', 'become'), ('become', 'a'), ('a', 'hallmark'), ('hallmark', 'of'), ('of', 'his'), ('his', 'military'), ('military', 'strategy'), ('strategy', '.'), ('.', 'As'), ('As', 'his'), ('his', 'conquests'), ('conquests', 'grew'), ('grew', ','), (',', 'he'), ('he', 'formed'), ('formed', 'alliances'), ('alliances', 'with'), ('with', 'local'), ('local', 'leaders'), ('leaders', ','), (',', 'securing'), ('securing', 'key'), ('key', 'forts'), ('forts', 'like'), ('like', 'Raigad'), ('Raigad', ','), (',', 'Kondana'), ('Kondana', ','), (',', 'and'), ('and', 'Purandar'), ('Purandar', ','), (',', 'establishing'), ('establishing', 'a'), ('a', 'solid'), ('solid', 'territorial'), ('territorial', 'base'), ('base', 'in'), ('in', 'western'), ('western', 'India'), ('India', '.'), ('.', 'In'), ('In', '1659'), ('1659', ','), (',', 'he'), ('he', 'faced'), ('faced', 'and'), ('and', 'defeated'), ('defeated', 'Afzal'), ('Afzal', 'Khan'), ('Khan', ','), (',', 'a'), ('a', 'prominent'), ('prominent', 'general'), ('general', 'of'), ('of', 'the'), ('the', 'Bijapur'), ('Bijapur', 'Sultanate'), ('Sultanate', ','), (',', 'solidifying'), ('solidifying', 'his'), ('his', 'reputation'), ('reputation', 'as'), ('as', 'a'), ('a', 'brave'), ('brave', 'and'), ('and', 'tactical'), ('tactica ...

# %%
# Generate trigrams
trigrams_list = list(blob.ngrams(n=3))
print("Trigrams:", trigrams_list)
# Out:
# Trigrams: [WordList(['Chhatrapati', 'Shivaji', 'Maharaj']), WordList(['Shivaji', 'Maharaj', 'was']), WordList(['Maharaj', 'was', 'born']), WordList(['was', 'born', 'on']), WordList(['born', 'on', 'February']), WordList(['on', 'February', '19']), WordList(['February', '19', '1630']), WordList(['19', '1630', 'at']), WordList(['1630', 'at', 'Shivneri']), WordList(['at', 'Shivneri', 'Fort']), WordList(['Shivneri', 'Fort', 'in']), WordList(['Fort', 'in', 'Maharashtra']), WordList(['in', 'Maharashtra', 'to']), WordList(['Maharashtra', 'to', 'Shahaji']), WordList(['to', 'Shahaji', 'Bhonsle']), WordList(['Shahaji', 'Bhonsle', 'a']), WordList(['Bhonsle', 'a', 'Maratha']), WordList(['a', 'Maratha', 'general']), WordList(['Maratha', 'general', 'and']), WordList(['general', 'and', 'Jijabai']), WordList(['and', 'Jijabai', 'who']), WordList(['Jijabai', 'who', 'deeply']), WordList(['who', 'deeply', 'influenced']), WordList(['deeply', 'influenced', 'Shivaji']), WordList(['influenced', 'Shivaji', 'with']), WordList(['Shivaji', 'with', 'her']), WordList(['with', 'her', 'teachings']), WordList(['her', 'teachings', 'on']), WordList(['teachings', 'on', 'dharma']), WordList(['on', 'dharma', 'bravery']), WordList(['dharma', 'bravery', 'and']), WordList(['bravery', 'and', 'justice']), WordList(['and', 'justice', 'From']), WordList(['justice', 'From', 'an']), WordList(['From', 'an', 'early']), WordList(['an', 'early', 'age']), WordList(['early', 'age', 'Shivaji']), WordList(['age', 'Shivaji', 'exhibited']), WordList(['Shivaji', 'exhibited', 'remarkable']), WordList(['exhibited', 'remarkable', 'leadership']), WordList(['remarkable', 'leadership', 'qualities']), WordList(['leadership', 'qualities', 'forming']), WordList(['qualities', 'forming', 'a']), WordList(['forming', 'a', 'group']), WordList(['a', 'group', 'of']), WordList(['group', 'of', 'loyal']), WordList(['of', 'loyal', 'followers']), WordList(['loyal', 'followers', 'and']), WordList(['followers', 'and', 'honing']), WordList(['and', 'honing', 'his']), WordList(['honing', 'his', 'military']), WordList(['his', 'military', 'skills']), WordList(['military', 'skills', 'in']), WordList(['skills', 'in', 'the']), WordList(['in', 'the', 'rugged']), WordList(['the', 'rugged', 'terrain']), WordList(['rugged', 'terrain', 'of']), WordList(['terrain', 'of', 'the']), WordList(['of', 'the', 'Sahyadri']), WordList(['the', 'Sahyadri', 'mountains']), WordList(['Sahyadri', 'mountains', 'He']), WordList(['mountains', 'He', 'grew']), WordList(['He', 'grew', 'up']), WordList(['grew', 'up', 'during']), WordList(['up', 'during', 'a']), WordList(['during', 'a', 'time']), WordList(['a', 'time', 'when']), WordList(['time', 'when', 'the']), WordList(['when', 'the', 'Mughal']), WordList(['the', 'Mughal', 'Empire']), WordList(['Mughal', 'Empire', 'under']), WordList(['Empire', 'under', 'Emperor']), WordList(['under', 'Emperor', 'Aurangzeb']), WordList(['Emperor', 'Aurangzeb', 'and']), WordList(['Aurangzeb', 'and', 'the']), WordList(['and', 'the', 'Deccan']), WordList(['the', 'Deccan', 'Sultanates']), WordList(['Deccan', 'Sultanates', 'were']), WordList(['Sultanates', 'were', 'vying']), WordList(['were', 'vying', 'for']), WordList(['vying', 'for', 'control']), WordList(['for', 'control', 'often']), WordList(['control', 'often', 'oppressing']), WordList(['often', 'oppressing', 'the']), WordList(['oppressing', 'the', 'local']), WordList(['the', 'local', 'population']), WordList(['local', 'population', 'which']), WordList(['population', 'which', 'deeply']), WordList(['which', 'deeply', 'disturbed']), WordList(['deeply', 'disturbed', 'him']), WordList(['disturbed', 'him', 'and']), WordList(['him', 'and', 'fueled']), WordList(['and', 'fueled', 'his']), WordList(['fueled', 'his', 'desire']), WordList(['his', 'desire', 'to']), WordList(['desire', 'to', 'establish']), WordList(['to', 'establish', 'Swarajya']), WordList(['establish', 'Swarajya', 'or']), WordList(['Swarajya', 'or', 'self-rule']), WordList(['or', 'self-rule', 'for']), W ...

# %% [markdown]
# ## 8- Frequency Distribution
#
# Use NLTK to compute the frequency distribution of words in the text.
#
# Find the 5 most common nouns in the text using spaCy.

# %%
from nltk import FreqDist, word_tokenize

# Tokenize and compute frequency distribution
tokens = word_tokenize(text)
freq_dist = FreqDist(tokens)
print("Frequency Distribution:", freq_dist.most_common())
# Out:
# Frequency Distribution: [(',', 51), ('and', 26), ('his', 22), ('the', 19), ('.', 16), ('to', 15), ('a', 14), ('of', 13), ('in', 10), ('Shivaji', 9), ('for', 7), ('him', 6), ('Maratha', 5), ('’', 5), ('s', 5), ('was', 4), ('on', 4), ('with', 4), ('Empire', 4), ('he', 4), ('India', 4), ('at', 3), ('Fort', 3), ('an', 3), ('military', 3), ('grew', 3), ('that', 3), ('Raigad', 3), ('establishing', 3), ('as', 3), ('forces', 3), ('Chhatrapati', 2), ('Maharaj', 2), ('Maharashtra', 2), ('general', 2), ('deeply', 2), ('justice', 2), ('age', 2), ('He', 2), ('up', 2), ('time', 2), ('Mughal', 2), ('Aurangzeb', 2), ('Deccan', 2), ('control', 2), ('local', 2), ('establish', 2), ('Swarajya', 2), ('first', 2), ('guerrilla', 2), ('tactics', 2), ('As', 2), ('key', 2), ('In', 2), (';', 2), ('crucial', 2), ('much', 2), ('territories', 2), ('from', 2), ('powerful', 2), ('foreign', 2), ('allowing', 2), ('becoming', 2), ('administrative', 2), ('people', 2), ('governance', 2), ('religious', 2), ('empire', 2), ('women', 2), ('His', 2), ('respect', 2), ('expand', 2), ('legacy', 2), ('born', 1), ('February', 1), ('19', 1), ('1630', 1), ('Shivneri', 1), ('Shahaji', 1), ('Bhonsle', 1), ('Jijabai', 1), ('who', 1), ('influenced', 1), ('her', 1), ('teachings', 1), ('dharma', 1), ('bravery', 1), ('From', 1), ('early', 1), ('exhibited', 1), ('remarkable', 1), ('leadership', 1), ('qualities', 1), ('forming', 1), ('group', 1), ('loyal', 1), ('followers', 1), ('honing', 1), ('skills', 1), ('rugged', 1), ('terrain', 1), ('Sahyadri', 1), ('mountains', 1), ('during', 1), ('when', 1), ('under', 1), ('Emperor', 1), ('Sultanates', 1), ('were', 1), ('vying', 1), ('often', 1), ('oppressing', 1), ('population', 1), ('which', 1), ('disturbed', 1), ('fueled', 1), ('desire', 1), ('or', 1), ('self-rule', 1), ('Marathas', 1), ('By', 1), ('16', 1), ('had', 1), ('captured', 1), ('fort', 1), ('Torna', 1), ('using', 1), ('warfare', 1), ('would', 1), ('later', 1), ('become', 1), ('hallmark', 1), ('strategy', 1), ('conquests', 1), ('formed', 1), ('alliances', 1), ('leaders', 1), ('securing', 1), ('forts', 1), ('like', 1), ('Kondana', 1), ('Purandar', 1), ('solid', 1), ('territorial', 1), ('base', 1), ('western', 1), ('1659', 1), ('faced', 1), ('defeated', 1), ('Afzal', 1), ('Khan', 1), ('prominent', 1), ('Bijapur', 1), ('Sultanate', 1), ('solidifying', 1), ('reputation', 1), ('brave', 1), ('tactical', 1), ('leader', 1), ('this', 1), ('victory', 1), ('over', 1), ('raids', 1), ('escape', 1), ('clutches', 1), ('Agra', 1), ('1666', 1), ('further', 1), ('bolstered', 1), ('legend', 1), ('realized', 1), ('navy', 1), ('safeguard', 1), ('invasions', 1), ('leading', 1), ('develop', 1), ('one', 1), ('earliest', 1), ('organized', 1), ('naval', 1), ('secure', 1), ('coastal', 1), ('areas', 1), ('against', 1), ('Portuguese', 1), ('British', 1), ('Siddis', 1), ('1674', 1), ('formally', 1), ('crowned', 1), ('himself', 1), ('declaring', 1), ('independence', 1), ('thus', 1), ('king', 1), ('Hindavi', 1), ('autonomous', 1), ('kingdom', 1), ('structured', 1), ('framework', 1), ('rooted', 1), ('Indian', 1), ('ethos', 1), ('system', 1), ('highly', 1), ('efficient', 1), ('emphasized', 1), ('welfare', 1), ('setting', 1), ('systems', 1), ('reduce', 1), ('corruption', 1), ('create', 1), ('fair', 1), ('tax', 1), ('structure', 1), ('Ashta', 1), ('Pradhan', 1), ('(', 1), ('Council', 1), ('Eight', 1), ('Ministers', 1), (')', 1), ('included', 1), ('departments', 1), ('finance', 1), ('internal', 1), ('affairs', 1), ('policy', 1), ('ensure', 1), ('smooth', 1), ('showed', 1), ('progressive', 1), ('approach', 1), ('towards', 1), ('promoting', 1), ('tolerance', 1), ('respecting', 1), ('diversity', 1), ('within', 1), ('even', 1), ('appointing', 1), ('Muslims', 1), ('positions', 1), ('administration', 1), ('banning', 1), ('harassment', 1), ('looting', 1), ('sites', 1), ('advocacy', 1), ('inspired', 1), ('trust', 1), ('loyalty', 1), ('among', 1), ('making', 1), ('ideal', 1), ('ruler', 1), ('known', 1), ('“', 1), ('Ganimi', 1 ...

# %%
import spacy
from collections import Counter

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Process the text
doc = nlp(text)

# Extract and count nouns
nouns = [token.text for token in doc if token.pos_ == "NOUN"]
noun_freq = Counter(nouns)
print("5 Most Common Nouns:", noun_freq.most_common(5))
# Out:
# 5 Most Common Nouns: [('forces', 3), ('general', 2), ('justice', 2), ('age', 2), ('time', 2)]

# %% [markdown]
# ## 9- Dependency Parsing
#
# Extract and display dependency parse information for each sentence using spaCy.
#
# Visualize the dependency tree of the first sentence using spaCy’s displacy tool.

# %%
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Process the text
doc = nlp(text)

# Extract dependency parse information
for token in doc:
    print(f"Text: {token.text}, Dependency: {token.dep_}, Head Text: {token.head.text}, POS: {token.pos_}")
# Out:
# Text: Chhatrapati, Dependency: compound, Head Text: Maharaj, POS: PROPN
# Text: Shivaji, Dependency: compound, Head Text: Maharaj, POS: PROPN
# Text: Maharaj, Dependency: nsubjpass, Head Text: born, POS: PROPN
# Text: was, Dependency: auxpass, Head Text: born, POS: AUX
# Text: born, Dependency: ROOT, Head Text: born, POS: VERB
# Text: on, Dependency: prep, Head Text: born, POS: ADP
# Text: February, Dependency: pobj, Head Text: on, POS: PROPN
# Text: 19, Dependency: nummod, Head Text: February, POS: NUM
# Text: ,, Dependency: punct, Head Text: February, POS: PUNCT
# Text: 1630, Dependency: nummod, Head Text: February, POS: NUM
# Text: ,, Dependency: punct, Head Text: February, POS: PUNCT
# Text: at, Dependency: prep, Head Text: born, POS: ADP
# Text: Shivneri, Dependency: compound, Head Text: Fort, POS: PROPN
# Text: Fort, Dependency: pobj, Head Text: at, POS: PROPN
# Text: in, Dependency: prep, Head Text: Fort, POS: ADP
# Text: Maharashtra, Dependency: pobj, Head Text: in, POS: PROPN
# Text: ,, Dependency: punct, Head Text: born, POS: PUNCT
# Text: to, Dependency: prep, Head Text: born, POS: ADP
# Text: Shahaji, Dependency: compound, Head Text: Bhonsle, POS: PROPN
# Text: Bhonsle, Dependency: pobj, Head Text: to, POS: PROPN
# Text: ,, Dependency: punct, Head Text: Bhonsle, POS: PUNCT
# Text: a, Dependency: det, Head Text: general, POS: DET
# Text: Maratha, Dependency: compound, Head Text: general, POS: PROPN
# Text: general, Dependency: appos, Head Text: Bhonsle, POS: NOUN
# Text: ,, Dependency: punct, Head Text: Bhonsle, POS: PUNCT
# Text: and, Dependency: cc, Head Text: Bhonsle, POS: CCONJ
# Text: Jijabai, Dependency: conj, Head Text: Bhonsle, POS: PROPN
# Text: ,, Dependency: punct, Head Text: Jijabai, POS: PUNCT
# Text: who, Dependency: nsubj, Head Text: influenced, POS: PRON
# Text: deeply, Dependency: advmod, Head Text: influenced, POS: ADV
# Text: influenced, Dependency: relcl, Head Text: Jijabai, POS: VERB
# Text: Shivaji, Dependency: dobj, Head Text: influenced, POS: PROPN
# Text: with, Dependency: prep, Head Text: influenced, POS: ADP
# Text: her, Dependency: poss, Head Text: teachings, POS: PRON
# Text: teachings, Dependency: pobj, Head Text: with, POS: NOUN
# Text: on, Dependency: prep, Head Text: teachings, POS: ADP
# Text: dharma, Dependency: pobj, Head Text: on, POS: NOUN
# Text: ,, Dependency: punct, Head Text: dharma, POS: PUNCT
# Text: bravery, Dependency: conj, Head Text: dharma, POS: NOUN
# Text: ,, Dependency: punct, Head Text: bravery, POS: PUNCT
# Text: and, Dependency: cc, Head Text: bravery, POS: CCONJ
# Text: justice, Dependency: conj, Head Text: bravery, POS: NOUN
# Text: ., Dependency: punct, Head Text: born, POS: PUNCT
# Text: From, Dependency: prep, Head Text: exhibited, POS: ADP
# Text: an, Dependency: det, Head Text: age, POS: DET
# Text: early, Dependency: amod, Head Text: age, POS: ADJ
# Text: age, Dependency: pobj, Head Text: From, POS: NOUN
# Text: ,, Dependency: punct, Head Text: exhibited, POS: PUNCT
# Text: Shivaji, Dependency: nsubj, Head Text: exhibited, POS: PROPN
# Text: exhibited, Dependency: ROOT, Head Text: exhibited, POS: VERB
# Text: remarkable, Dependency: amod, Head Text: qualities, POS: ADJ
# Text: leadership, Dependency: compound, Head Text: qualities, POS: NOUN
# Text: qualities, Dependency: dobj, Head Text: exhibited, POS: NOUN
# Text: ,, Dependency: punct, Head Text: exhibited, POS: PUNCT
# Text: forming, Dependency: advcl, Head Text: exhibited, POS: VERB
# Text: a, Dependency: det, Head Text: group, POS: DET
# Text: group, Dependency: dobj, Head Text: forming, POS: NOUN
# Text: of, Dependency: prep, Head Text: group, POS: ADP
# Text: loyal, Dependency: amod, Head Text: followers, POS: ADJ
# Text: followers, Dependency: pobj, Head Text: of, POS: NOUN
# Text: and, Dependency: cc, Head Text: forming, POS: CCONJ
# Text: honing, Dependency: conj, Head Text: forming, POS: VERB
# Text: his, Dependency: poss, Head Text: skills, POS: PRON
# Text: military, Dependency: amod, Head Text: skills, POS: ADJ
# Text: skills, Dependency: dobj, Head Text: honing, POS: NOUN
# Text: in, Dependency: prep, Head Text: honing, POS: ADP
# Text: the, Dependency: det, Head Text: terrain, POS: DET
# Text: rugged, Dependency: amod, Head Text: terrain, POS: ADJ
# Text: terrain, Dependency: pobj, Head Text: in, POS: NOUN
# Text: of, Dependency: prep, Head Text: terrain, POS: ADP
# Text: the, Dependency: det, Head Text: mountains, POS: DET
# Text: Sahyadri, Dependency: compound, Head Text: mountains, POS: PROPN
# Text: mountains, Dependency: pobj, Head Text: of, POS: NOUN
# Text: ., Dependency: punct, Head Text: exhibited, POS: PUNCT
# Text: He, Dependency: nsubj, Head Text: grew, POS: PRON
# Text: grew, Dependency: ROOT, Head Text: grew, POS: VERB
# Text: up, Dependency: prt, Head Text: grew, POS: ADP
# Text: during, Dependency: prep, Head Text: grew, POS: ADP
# Text: a, Dependency: det, Head Text: time, POS: DET
# Text: time, Dependency: pobj, Head Text: during, POS: NOUN
# Text: when, Dependency: advmod, Head Text: vying, POS: SCONJ
# Text: the, Dependency: det, Head Text: Empire, POS: DET
# Text: Mughal, Dependency: compound, Head Text: Empire, POS: PROPN
# Text: Empire, Dependency: nsubj, Head Text: vying, POS: PROPN
# Text: under, Dependency: prep, Head Text: Empire, POS: ADP
# Text: Emperor, Dependency: compound, Head Text: Aurangzeb, POS: PROPN
# Text: Aurangzeb, Dependency: pobj, Head Text: under, POS: PROPN
# Text: and, Dependency: cc, Head Text: Aurangzeb, POS: CCONJ
# Text: the, Dependency: det, Head Text: Sultanates, POS: DET
# Text: Deccan, Dependency: compound, Head Text: Sultanates, POS: PROPN
# Text: Sultanates, Dependency: conj, Head Text: Aurangzeb, POS: PROPN
# Text: were, Dependency: aux, Head Text: vying, POS: AUX
# Text: vying, Dependency: relcl, Head Text: time, POS: VERB
# Text: for, Dependency: prep, Head Text: vying, POS: ADP
# Text: control, Dependency: pobj, Head Text: for, POS: NOUN
# Text: ,, Dependency: punct, Head Text: grew, POS: PUNCT
# Text: often, Dependency: advmod, Head Text: oppressing, POS: ADV
# Text: oppressing, Dependency: advcl, Head Text: grew, POS: VERB
# Text: the, Dependency: det, Head Text: population, POS: DET
# Text: local, Dependency: amod, Head Text: population, POS: ADJ
# Text: population, Dependency: dobj, Head Text: oppressing, POS: NOUN
# Text: ,, Dependency: punct, Head Text: population, POS: PUNCT
# Text: which, Dependency: nsubj, Head Text: disturbed, POS: PRON
# Text: deeply, Dependency: advmod, Head Text: disturbed, POS: ADV
# Text: disturbed, Dependency: relcl, Head Text: population, POS: VERB
# Text: him, Dependency: dobj, Head Text: disturbed, POS: PRON
# Text: and, Dependency: cc, Head Text: disturbed, POS: CCONJ
# Text: fueled, Dependency: conj, Head Text: disturbed, POS: VERB
# Text: his, Dependency: poss, Head Text: desire, POS: PRON
# Text: desire, Dependency: dobj, Head Text: fueled, POS: NOUN
# Text: to, Dependency: aux, Head Text: establish, POS: PART
# Text: establish, Dependency: acl, Head Text: desire, POS: VERB
# Text: Swarajya, Dependency: dobj, Head Text: establish, POS: PROPN
# Text: ,, Dependency: punct, Head Text: Swarajya, POS: PUNCT
# Text: or, Dependency: cc, Head Text: Swarajya, POS: CCONJ
# Text: self, Dependency: compound, Head Text: rule, POS: NOUN
# Text: -, Dependency: punct, Head Text: rule, POS: PUNCT
# Text: rule, Dependency: conj, Head Text: Swarajya, POS: NOUN
# Text: for, Dependency: prep, Head Text: establish, POS: ADP
# Text: the, Dependency: det, Head Text: Marathas, POS: DET
# Text: Marathas, Dependency: pobj, Head Text: for, POS: PROPN
# Text: ., Dependency: punct, Head Text: grew, POS: PUNCT
# Text: By, Dependency: prep, Head Text: captured, POS: ADP
# Text: the, Dependency: det, Head Text: age, POS: DET
# Text: age, Dependency: pobj, Head Text: By, POS: NOUN
# Text: of, Dependency: prep, Head Text: age, POS: ADP
# Text: 16, Dependency: pobj, Head Text: of, POS: NUM
# Text: ,, Dependency: punct, Head Text: captured, POS: PUNCT
# Text: Shivaji, Dependency: nsubj, Head Text: captured, POS: PROPN
# Text: had, Dependency: aux, Head Text: captured, POS: AUX
# Text: captured, Dependency: ROOT, Head Text: captured, POS: VERB
# Text: his, Dependency: poss, Head Text: fort, POS: PRON
# Text: first, Dependency: amod, Head Text: fort, POS: ADJ
# Text: fort, Dependency: dobj, Head Text: captured, POS: NOUN
# Text: ,, Dependency: punct, Head Text: fort, POS: PUNCT
# Text: Torna, Dependency: appos, Head Text: fort, POS: PROPN
# Text: ,, Dependency: punct, Head Text: fort, POS: PUNCT
# Text: using, Dependency: advcl, Head Text: captured, POS: VERB
# Text: guerrilla, Dependency: compound, Head Text: warfare, POS: NOUN
# Text: warfare, Dependency: compound, Head Text: tactics, POS: NOUN
# Text: tactics, Dependency: dobj, Head Text: using, POS: NOUN
# Text: that, Dependency: nsubj, Head Text: become, POS: PRON
# Text: would, Dependency: aux, Head Text: become, POS: AUX
# Text: later, Dependency: advmod, Head Text: become, POS: ADV
# Text: become, Dependency: ccomp, Head Text: using, POS: VERB
# Text: a, Dependency: det, Head Text: hallmark, POS: DET
# Text: hallmark, Dependency: attr, Head Text: become, POS: NOUN
# Text: of, Dependency: prep, Head Text: hallmark, POS: ADP
# Text: his, Dependency: poss, Head Text: strategy, POS: PRON
# Text: military, Dependency: amod, Head Text: strategy, POS: ADJ
# Text: strategy, Dependency: pobj, Head Text: of, POS: NOUN
# Text: ., Dependency: punct, Head Text: captured, POS: PUNCT
# Text: As, Dependency: mark, Head Text: grew, POS: SCONJ
# Text: his, Dependency: poss, Head Text: conquests, POS: PRON
# Text: conquests, Dependency: nsubj, Head Text: grew, POS: NOUN
# Text: grew, Dependency: advcl, Head Text: formed, POS: VERB
# Text: ,, Dependency: punct, Head Text: formed, POS: PUNCT
# Text: he, Dependency: nsubj, Head Text: formed, POS: PRON
# Text: formed, Dependency: ROOT, Head Text: formed, POS: VERB
# Text: alliances, Dependency: dobj, Head Text: formed, POS: NOUN
# Text: with, Dependency: prep, Head Text: alliances, POS: ADP
# Text: local, Dependency: amod, Head Text: leaders, POS: ADJ
# Text: leaders, Dependency: pobj, Head Text: with, POS: NOUN
# Text: ,, Dependency: punct, Head Text: alliances, POS: PUNCT
# Text: securing, Dependency: advcl, Head Text: formed, POS: VERB
# Text: key, Dependency: amod, Head Text: forts, POS: ADJ
# Text: forts, Dependency: dobj, Head Text: securing, POS: NOUN
# Text: like, Dependency: prep, Head Text: forts, POS: ADP
# Text: Raigad, Dependency: pobj, Head Text: like, POS: PROPN
# Text: ,, Dependency: punct, Head Text: Raigad, POS: PUNCT
# Text: Kondana, Dependency: conj, Head Text: Raigad, POS: PROPN
# Text: ,, Dependency: punct, Head Text: Kondana, POS: PUNCT
# Text: and, Dependency: cc, Head Text: Kondana, POS: CCONJ
# Text: Purandar, Dependency: conj, Head Text: Kondana, POS: PROPN
# Text: ,, Dependency: punct, Head Text: securing, POS: PUNCT
# Text: establishing, Dependency: conj, Head Text: securing, POS: VERB
# Text: a, Dependency: det, Head Text: base, POS: DET
# Text: solid, Dependency: amod, Head Text: base, POS: ADJ
# Text: territorial, Dependency: amod, Head Text: base, POS: ADJ
# Text: base, Dependency: dobj, Head Text: establishing, POS: NOUN
# Text: in, Dependency: prep, Head Text: base, POS: ADP
# Text: western, Dependency: amod, Head Text: India, POS: ADJ
# Text: India, Dependency: pobj, Head Text: in, POS: PROPN
# Text: ., Dependency: punct, Head Text: formed, POS: PUNCT
# Text: In, Dependency: prep, Head Text: faced, POS: ADP
# Text: 1659, Dependency: pobj, Head Text: In, POS: NUM
# Text: ,, Dependency: punct, Head Text: faced, POS: PUNCT
# Text: he, Dependency: nsubj, Head Text: faced, POS: PRON
# Text: faced, Dependency: ccomp, Head Text: was, POS: VERB
# Text: and, Dependency: cc, Head Text: faced, POS: CCONJ
# Text: defeated, Dependency: conj, Head Text: faced, POS: VERB
# Text: Afzal, Dependency: compound, Head Text: Khan, POS: PROPN
# Text: Khan, Dependency: dobj, Head Text: defeated, POS: PROPN
# Text: ,, Dependency: punct, Head Text: Khan, POS: PUNCT
# Text: a, Dependency: det, Head Text: general, POS: DET
# Text: prominent, Dependency: amod, Head Text: general, POS: ADJ
# Text: general, Dependency: appos, Head Text: Khan, POS: NOUN
# Text: of, Dependency: prep, Head Text: general, POS: ADP
# Text: the, Dependency: det, Head Text: Sultanate, POS: DET
# Text: Bijapur, Dependency: compound, Head Text: Sultanate, POS: PROPN
# Text: Sultanate, Dependency: pobj, Head Text: of, POS: PROPN
# Text: ,, Dependency: punct, Head Text: Khan, POS: PUNCT
# Text: solidifying, Dependency: advcl, Head Text: defeated, POS: VERB
# Text: his, Dependency: poss, Head Text: reputation, POS: PRON
# Text: reputation, Dependency: dobj, Head Text: solidifying, POS: NOUN
# Text: as, Dependency: prep, Head Text: reputation, POS: ADP
# Text: a, Dependency: det, Head Text: leader, POS: DET
# Text: brave, Dependency: amod, Head Text: leader, POS: ADJ
# Text: and, Dependency: cc, Head Text: brave, POS: CCONJ
# Text: tactical, Dependency: conj, Head Text: brave, POS: ADJ
# Text: leader, Dependency: pobj, Head Text: as, POS: NOUN
# Text: ;, Dependency: punct, Head Text: was, POS: PUNCT
# Text: this, Dependency: det, Head Text: victory, POS: DET
# Text: victory, Dependency: nsubj, Head Text: was, POS: NOUN
# Text: was, Dependency: ROOT, Head Text: was, POS: AUX
# Text: crucial, Dependency: acomp, Head Text: was, POS: ADJ
# Text: in, Dependency: prep, Head Text: was, POS: ADP
# Text: establishing, Dependency: pcomp, Head Text: in, POS: VERB
# Text: his, Dependency: poss, Head Text: control, POS: PRON
# Text: control, Dependency: dobj, Head Text: establishing, POS: NOUN
# Text: over, Dependency: prep, Head Text: establishing, POS: ADP
# Text: much, Dependency: pobj, Head Text: over, POS: ADJ
# Text: of, Dependency: prep, Head Text: much, POS: ADP
# Text: the, Dependency: det, Head Text: Deccan, POS: DET
# Text: Deccan, Dependency: pobj, Head Text: of, POS: PROPN
# Text: ., Dependency: punct, Head Text: was, POS: PUNCT
# Text: Shivaji, Dependency: poss, Head Text: raids, POS: PROPN
# Text: ’s, Dependency: case, Head Text: Shivaji, POS: PART
# Text: raids, Dependency: nsubj, Head Text: bolstered, POS: NOUN
# Text: on, Dependency: prep, Head Text: raids, POS: ADP
# Text: Mughal, Dependency: compound, Head Text: territories, POS: PROPN
# Text: territories, Dependency: pobj, Head Text: on, POS: NOUN
# Text: and, Dependency: cc, Head Text: territories, POS: CCONJ
# Text: his, Dependency: poss, Head Text: escape, POS: PRON
# Text: escape, Dependency: conj, Head Text: territories, POS: NOUN
# Text: from, Dependency: prep, Head Text: escape, POS: ADP
# Text: the, Dependency: det, Head Text: clutches, POS: DET
# Text: clutches, Dependency: pobj, Head Text: from, POS: NOUN
# Text: of, Dependency: prep, Head Text: clutches, POS: ADP
# Text: Aurangzeb, Dependency: pobj, Head Text: of, POS: PROPN
# Text: in, Dependency: prep, Head Text: clutches, POS: ADP
# Text: Agra, Dependency: pobj, Head Text: in, POS: PROPN
# Text: in, Dependency: prep, Head Text: raids, POS: ADP
# Text: 1666, Dependency: pobj, Head Text: in, POS: NUM
# Text: further, Dependency: advmod, Head Text: bolstered, POS: ADV
# Text: bolstered, Dependency: ROOT, Head Text: bolstered, POS: VERB
# Text: his, Dependency: poss, Head Text: legend, POS: PRON
# Text: legend, Dependency: dobj, Head Text: bolstered, POS: NOUN
# Text: ., Dependency: punct, Head Text: bolstered, POS: PUNCT
# Text: He, Dependency: nsubj, Head Text: realized, POS: PRON
# Text: realized, Dependency: ROOT, Head Text: realized, POS: VERB
# Text: that, Dependency: mark, Head Text: was, POS: SCONJ
# Text: a, Dependency: det, Head Text: navy, POS: DET
# Text: powerful, Dependency: amod, Head Text: navy, POS: ADJ
# Text: navy, Dependency: nsubj, Head Text: was, POS: NOUN
# Text: was, Dependency: ccomp, Head Text: realized, POS: AUX
# Text: crucial, Dependency: acomp, Head Text: was, POS: ADJ
# Text: to, Dependency: aux, Head Text: safeguard, POS: PART
# Text: safeguard, Dependency: xcomp, Head Text: crucial, POS: VERB
# Text: his, Dependency: poss, Head Text: territories, POS: PRON
# Text: territories, Dependency: dobj, Head Text: safeguard, POS: NOUN
# Text: from, Dependency: prep, Head Text: territories, POS: ADP
# Text: foreign, Dependency: amod, Head Text: invasions, POS: ADJ
# Text: invasions, Dependency: pobj, Head Text: from, POS: NOUN
# Text: ,, Dependency: punct, Head Text: was, POS: PUNCT
# Text: leading, Dependency: advcl, Head Text: realized, POS: VERB
# Text: him, Dependency: dobj, Head Text: leading, POS: PRON
# Text: to, Dependency: aux, Head Text: develop, POS: PART
# Text: develop, Dependency: xcomp, Head Text: leading, POS: VERB
# Text: one, Dependency: dobj, Head Text: develop, POS: NUM
# Text: of, Dependency: prep, Head Text: one, POS: ADP
# Text: the, Dependency: det, Head Text: forces, POS: DET
# Text: earliest, Dependency: amod, Head Text: forces, POS: ADJ
# Text: organized, Dependency: amod, Head Text: forces, POS: VERB
# Text: naval, Dependency: amod, Head Text: forces, POS: ADJ
# Text: forces, Dependency: pobj, Head Text: of, POS: NOUN
# Text: in, Dependency: prep, Head Text: forces, POS: ADP
# Text: India, Dependency: pobj, Head Text: in, POS: PROPN
# Text: ,, Dependency: punct, Head Text: develop, POS: PUNCT
# Text: allowing, Dependency: advcl, Head Text: develop, POS: VERB
# Text: him, Dependency: nsubj, Head Text: secure, POS: PRON
# Text: to, Dependency: aux, Head Text: secure, POS: PART
# Text: secure, Dependency: ccomp, Head Text: allowing, POS: VERB
# Text: coastal, Dependency: amod, Head Text: areas, POS: ADJ
# Text: areas, Dependency: dobj, Head Text: secure, POS: NOUN
# Text: against, Dependency: prep, Head Text: areas, POS: ADP
# Text: Portuguese, Dependency: pobj, Head Text: against, POS: ADJ
# Text: ,, Dependency: punct, Head Text: Portuguese, POS: PUNCT
# Text: British, Dependency: conj, Head Text: Portuguese, POS: ADJ
# Text: ,, Dependency: punct, Head Text: British, POS: PUNCT
# Text: and, Dependency: cc, Head Text: British, POS: CCONJ
# Text: Siddis, Dependency: compound, Head Text: forces, POS: PROPN
# Text: forces, Dependency: conj, Head Text: British, POS: NOUN
# Text: ., Dependency: punct, Head Text: realized, POS: PUNCT
# Text: In, Dependency: prep, Head Text: crowned, POS: ADP
# Text: 1674, Dependency: pobj, Head Text: In, POS: NUM
# Text: ,, Dependency: punct, Head Text: crowned, POS: PUNCT
# Text: he, Dependency: nsubj, Head Text: crowned, POS: PRON
# Text: formally, Dependency: advmod, Head Text: crowned, POS: ADV
# Text: crowned, Dependency: ROOT, Head Text: crowned, POS: VERB
# Text: himself, Dependency: dobj, Head Text: crowned, POS: PRON
# Text: as, Dependency: prep, Head Text: crowned, POS: ADP
# Text: Chhatrapati, Dependency: pobj, Head Text: as, POS: PROPN
# Text: at, Dependency: prep, Head Text: Chhatrapati, POS: ADP
# Text: Raigad, Dependency: compound, Head Text: Fort, POS: PROPN
# Text: Fort, Dependency: pobj, Head Text: at, POS: PROPN
# Text: ,, Dependency: punct, Head Text: crowned, POS: PUNCT
# Text: declaring, Dependency: advcl, Head Text: crowned, POS: VERB
# Text: his, Dependency: poss, Head Text: independence, POS: PRON
# Text: independence, Dependency: dobj, Head Text: declaring, POS: NOUN
# Text: and, Dependency: cc, Head Text: declaring, POS: CCONJ
# Text: establishing, Dependency: conj, Head Text: declaring, POS: VERB
# Text: the, Dependency: det, Head Text: Empire, POS: DET
# Text: Maratha, Dependency: compound, Head Text: Empire, POS: PROPN
# Text: Empire, Dependency: dobj, Head Text: establishing, POS: PROPN
# Text: ,, Dependency: punct, Head Text: establishing, POS: PUNCT
# Text: thus, Dependency: advmod, Head Text: becoming, POS: ADV
# Text: becoming, Dependency: advcl, Head Text: establishing, POS: VERB
# Text: the, Dependency: det, Head Text: king, POS: DET
# Text: first, Dependency: amod, Head Text: king, POS: ADJ
# Text: king, Dependency: attr, Head Text: becoming, POS: NOUN
# Text: to, Dependency: aux, Head Text: establish, POS: PART
# Text: establish, Dependency: relcl, Head Text: king, POS: VERB
# Text: Hindavi, Dependency: compound, Head Text: Swarajya, POS: PROPN
# Text: Swarajya, Dependency: dobj, Head Text: establish, POS: PROPN
# Text: ,, Dependency: punct, Head Text: Swarajya, POS: PUNCT
# Text: an, Dependency: det, Head Text: kingdom, POS: DET
# Text: autonomous, Dependency: amod, Head Text: kingdom, POS: ADJ
# Text: kingdom, Dependency: appos, Head Text: Swarajya, POS: NOUN
# Text: with, Dependency: prep, Head Text: kingdom, POS: ADP
# Text: a, Dependency: det, Head Text: framework, POS: DET
# Text: structured, Dependency: amod, Head Text: framework, POS: ADJ
# Text: administrative, Dependency: amod, Head Text: framework, POS: ADJ
# Text: framework, Dependency: pobj, Head Text: with, POS: NOUN
# Text: rooted, Dependency: acl, Head Text: framework, POS: VERB
# Text: in, Dependency: prep, Head Text: rooted, POS: ADP
# Text: Indian, Dependency: amod, Head Text: ethos, POS: ADJ
# Text: ethos, Dependency: pobj, Head Text: in, POS: NOUN
# Text: ., Dependency: punct, Head Text: crowned, POS: PUNCT
# Text: Shivaji, Dependency: poss, Head Text: system, POS: PROPN
# Text: ’s, Dependency: case, Head Text: Shivaji, POS: PART
# Text: administrative, Dependency: amod, Head Text: system, POS: ADJ
# Text: system, Dependency: nsubj, Head Text: was, POS: NOUN
# Text: was, Dependency: ROOT, Head Text: was, POS: AUX
# Text: highly, Dependency: advmod, Head Text: efficient, POS: ADV
# Text: efficient, Dependency: acomp, Head Text: was, POS: ADJ
# Text: ,, Dependency: punct, Head Text: was, POS: PUNCT
# Text: and, Dependency: cc, Head Text: was, POS: CCONJ
# Text: he, Dependency: nsubj, Head Text: emphasized, POS: PRON
# Text: emphasized, Dependency: ccomp, Head Text: included, POS: VERB
# Text: the, Dependency: det, Head Text: welfare, POS: DET
# Text: welfare, Dependency: dobj, Head Text: emphasized, POS: NOUN
# Text: of, Dependency: prep, Head Text: welfare, POS: ADP
# Text: his, Dependency: poss, Head Text: people, POS: PRON
# Text: people, Dependency: pobj, Head Text: of, POS: NOUN
# Text: ,, Dependency: punct, Head Text: emphasized, POS: PUNCT
# Text: setting, Dependency: advcl, Head Text: emphasized, POS: VERB
# Text: up, Dependency: prt, Head Text: setting, POS: ADP
# Text: systems, Dependency: dobj, Head Text: setting, POS: NOUN
# Text: to, Dependency: aux, Head Text: reduce, POS: PART
# Text: reduce, Dependency: advcl, Head Text: setting, POS: VERB
# Text: corruption, Dependency: dobj, Head Text: reduce, POS: NOUN
# Text: and, Dependency: cc, Head Text: reduce, POS: CCONJ
# Text: create, Dependency: conj, Head Text: reduce, POS: VERB
# Text: a, Dependency: det, Head Text: structure, POS: DET
# Text: fair, Dependency: amod, Head Text: structure, POS: ADJ
# Text: tax, Dependency: compound, Head Text: structure, POS: NOUN
# Text: structure, Dependency: dobj, Head Text: create, POS: NOUN
# Text: ;, Dependency: punct, Head Text: included, POS: PUNCT
# Text: his, Dependency: poss, Head Text: Pradhan, POS: PRON
# Text: Ashta, Dependency: compound, Head Text: Pradhan, POS: PROPN
# Text: Pradhan, Dependency: nsubj, Head Text: included, POS: PROPN
# Text: (, Dependency: punct, Head Text: Pradhan, POS: PUNCT
# Text: Council, Dependency: appos, Head Text: Pradhan, POS: PROPN
# Text: of, Dependency: prep, Head Text: Council, POS: ADP
# Text: Eight, Dependency: nummod, Head Text: Ministers, POS: PROPN
# Text: Ministers, Dependency: pobj, Head Text: of, POS: PROPN
# Text: ), Dependency: punct, Head Text: Pradhan, POS: PUNCT
# Text: included, Dependency: conj, Head Text: was, POS: VERB
# Text: departments, Dependency: dobj, Head Text: included, POS: NOUN
# Text: for, Dependency: prep, Head Text: departments, POS: ADP
# Text: finance, Dependency: pobj, Head Text: for, POS: NOUN
# Text: ,, Dependency: punct, Head Text: finance, POS: PUNCT
# Text: internal, Dependency: amod, Head Text: affairs, POS: ADJ
# Text: affairs, Dependency: conj, Head Text: finance, POS: NOUN
# Text: ,, Dependency: punct, Head Text: affairs, POS: PUNCT
# Text: foreign, Dependency: amod, Head Text: policy, POS: ADJ
# Text: policy, Dependency: conj, Head Text: affairs, POS: NOUN
# Text: ,, Dependency: punct, Head Text: policy, POS: PUNCT
# Text: and, Dependency: cc, Head Text: policy, POS: CCONJ
# Text: military, Dependency: conj, Head Text: policy, POS: NOUN
# Text: to, Dependency: aux, Head Text: ensure, POS: PART
# Text: ensure, Dependency: advcl, Head Text: military, POS: VERB
# Text: smooth, Dependency: amod, Head Text: governance, POS: ADJ
# Text: governance, Dependency: dobj, Head Text: ensure, POS: NOUN
# Text: ., Dependency: punct, Head Text: included, POS: PUNCT
# Text: Shivaji, Dependency: nsubj, Head Text: showed, POS: PROPN
# Text: showed, Dependency: ROOT, Head Text: showed, POS: VERB
# Text: a, Dependency: det, Head Text: approach, POS: DET
# Text: progressive, Dependency: amod, Head Text: approach, POS: ADJ
# Text: approach, Dependency: dobj, Head Text: showed, POS: NOUN
# Text: towards, Dependency: prep, Head Text: approach, POS: ADP
# Text: governance, Dependency: pobj, Head Text: towards, POS: NOUN
# Text: ,, Dependency: punct, Head Text: showed, POS: PUNCT
# Text: promoting, Dependency: advcl, Head Text: showed, POS: VERB
# Text: religious, Dependency: amod, Head Text: tolerance, POS: ADJ
# Text: tolerance, Dependency: dobj, Head Text: promoting, POS: NOUN
# Text: and, Dependency: cc, Head Text: promoting, POS: CCONJ
# Text: respecting, Dependency: conj, Head Text: promoting, POS: VERB
# Text: the, Dependency: det, Head Text: diversity, POS: DET
# Text: diversity, Dependency: dobj, Head Text: respecting, POS: NOUN
# Text: within, Dependency: prep, Head Text: diversity, POS: ADP
# Text: his, Dependency: poss, Head Text: empire, POS: PRON
# Text: empire, Dependency: pobj, Head Text: within, POS: NOUN
# Text: ,, Dependency: punct, Head Text: promoting, POS: PUNCT
# Text: even, Dependency: advmod, Head Text: appointing, POS: ADV
# Text: appointing, Dependency: conj, Head Text: promoting, POS: VERB
# Text: Muslims, Dependency: dobj, Head Text: appointing, POS: PROPN
# Text: to, Dependency: prep, Head Text: appointing, POS: ADP
# Text: key, Dependency: amod, Head Text: positions, POS: ADJ
# Text: positions, Dependency: pobj, Head Text: to, POS: NOUN
# Text: in, Dependency: prep, Head Text: positions, POS: ADP
# Text: his, Dependency: poss, Head Text: administration, POS: PRON
# Text: administration, Dependency: pobj, Head Text: in, POS: NOUN
# Text: and, Dependency: cc, Head Text: appointing, POS: CCONJ
# Text: banning, Dependency: conj, Head Text: appointing, POS: VERB
# Text: the, Dependency: det, Head Text: harassment, POS: DET
# Text: harassment, Dependency: dobj, Head Text: banning, POS: NOUN
# Text: of, Dependency: prep, Head Text: harassment, POS: ADP
# Text: women, Dependency: pobj, Head Text: of, POS: NOUN
# Text: and, Dependency: cc, Head Text: women, POS: CCONJ
# Text: looting, Dependency: conj, Head Text: women, POS: NOUN
# Text: of, Dependency: prep, Head Text: looting, POS: ADP
# Text: religious, Dependency: amod, Head Text: sites, POS: ADJ
# Text: sites, Dependency: pobj, Head Text: of, POS: NOUN
# Text: ., Dependency: punct, Head Text: showed, POS: PUNCT
# Text: His, Dependency: poss, Head Text: respect, POS: PRON
# Text: respect, Dependency: nsubj, Head Text: inspired, POS: NOUN
# Text: for, Dependency: prep, Head Text: respect, POS: ADP
# Text: women, Dependency: pobj, Head Text: for, POS: NOUN
# Text: and, Dependency: cc, Head Text: women, POS: CCONJ
# Text: his, Dependency: poss, Head Text: advocacy, POS: PRON
# Text: advocacy, Dependency: conj, Head Text: women, POS: NOUN
# Text: for, Dependency: prep, Head Text: advocacy, POS: ADP
# Text: justice, Dependency: pobj, Head Text: for, POS: NOUN
# Text: inspired, Dependency: ROOT, Head Text: inspired, POS: VERB
# Text: trust, Dependency: dobj, Head Text: inspired, POS: NOUN
# Text: and, Dependency: cc, Head Text: trust, POS: CCONJ
# Text: loyalty, Dependency: conj, Head Text: trust, POS: NOUN
# Text: among, Dependency: prep, Head Text: inspired, POS: ADP
# Text: his, Dependency: poss, Head Text: people, POS: PRON
# Text: people, Dependency: pobj, Head Text: among, POS: NOUN
# Text: ,, Dependency: punct, Head Text: inspired, POS: PUNCT
# Text: making, Dependency: advcl, Head Text: inspired, POS: VERB
# Text: him, Dependency: nsubj, Head Text: ruler, POS: PRON
# Text: an, Dependency: det, Head Text: ruler, POS: DET
# Text: ideal, Dependency: amod, Head Text: ruler, POS: ADJ
# Text: ruler, Dependency: ccomp, Head Text: making, POS: NOUN
# Text: for, Dependency: prep, Head Text: ruler, POS: ADP
# Text: his, Dependency: poss, Head Text: time, POS: PRON
# Text: time, Dependency: pobj, Head Text: for, POS: NOUN
# Text: ., Dependency: punct, Head Text: inspired, POS: PUNCT
# Text: Shivaji, Dependency: compound, Head Text: Maharaj, POS: PROPN
# Text: Maharaj, Dependency: poss, Head Text: tactics, POS: PROPN
# Text: ’s, Dependency: case, Head Text: Maharaj, POS: PART
# Text: guerrilla, Dependency: compound, Head Text: tactics, POS: NOUN
# Text: tactics, Dependency: nsubj, Head Text: became, POS: NOUN
# Text: ,, Dependency: punct, Head Text: tactics, POS: PUNCT
# Text: known, Dependency: acl, Head Text: tactics, POS: VERB
# Text: as, Dependency: prep, Head Text: known, POS: ADP
# Text: “, Dependency: punct, Head Text: as, POS: PUNCT
# Text: Ganimi, Dependency: compound, Head Text: Kava, POS: PROPN
# Text: Kava, Dependency: pobj, Head Text: as, POS: PROPN
# Text: ,, Dependency: punct, Head Text: tactics, POS: PUNCT
# Text: ”, Dependency: punct, Head Text: tactics, POS: PUNCT
# Text: became, Dependency: ROOT, Head Text: became, POS: VERB
# Text: legendary, Dependency: acomp, Head Text: became, POS: ADJ
# Text: and, Dependency: cc, Head Text: became, POS: CCONJ
# Text: enabled, Dependency: conj, Head Text: became, POS: VERB
# Text: him, Dependency: dobj, Head Text: enabled, POS: PRON
# Text: to, Dependency: aux, Head Text: outmaneuver, POS: PART
# Text: outmaneuver, Dependency: xcomp, Head Text: enabled, POS: VERB
# Text: much, Dependency: advmod, Head Text: larger, POS: ADV
# Text: larger, Dependency: amod, Head Text: armies, POS: ADJ
# Text: and, Dependency: cc, Head Text: larger, POS: CCONJ
# Text: better, Dependency: advmod, Head Text: equipped, POS: ADV
# Text: -, Dependency: punct, Head Text: equipped, POS: PUNCT
# Text: equipped, Dependency: conj, Head Text: larger, POS: VERB
# Text: armies, Dependency: dobj, Head Text: outmaneuver, POS: NOUN
# Text: repeatedly, Dependency: advmod, Head Text: outmaneuver, POS: ADV
# Text: ,, Dependency: punct, Head Text: outmaneuver, POS: PUNCT
# Text: allowing, Dependency: advcl, Head Text: outmaneuver, POS: VERB
# Text: him, Dependency: nsubj, Head Text: expand, POS: PRON
# Text: to, Dependency: aux, Head Text: expand, POS: PART
# Text: expand, Dependency: ccomp, Head Text: allowing, POS: VERB
# Text: his, Dependency: poss, Head Text: empire, POS: PRON
# Text: empire, Dependency: dobj, Head Text: expand, POS: NOUN
# Text: while, Dependency: mark, Head Text: minimizing, POS: SCONJ
# Text: minimizing, Dependency: advcl, Head Text: expand, POS: VERB
# Text: losses, Dependency: dobj, Head Text: minimizing, POS: NOUN
# Text: ., Dependency: punct, Head Text: became, POS: PUNCT
# Text: As, Dependency: mark, Head Text: grew, POS: SCONJ
# Text: his, Dependency: poss, Head Text: fame, POS: PRON
# Text: fame, Dependency: nsubj, Head Text: grew, POS: NOUN
# Text: grew, Dependency: advcl, Head Text: began, POS: VERB
# Text: ,, Dependency: punct, Head Text: began, POS: PUNCT
# Text: the, Dependency: det, Head Text: Empire, POS: DET
# Text: Maratha, Dependency: compound, Head Text: Empire, POS: PROPN
# Text: Empire, Dependency: nsubj, Head Text: began, POS: PROPN
# Text: began, Dependency: ROOT, Head Text: began, POS: VERB
# Text: to, Dependency: aux, Head Text: influence, POS: PART
# Text: influence, Dependency: xcomp, Head Text: began, POS: VERB
# Text: regions, Dependency: dobj, Head Text: influence, POS: NOUN
# Text: far, Dependency: advmod, Head Text: beyond, POS: ADV
# Text: beyond, Dependency: prep, Head Text: influence, POS: ADP
# Text: Maharashtra, Dependency: pobj, Head Text: beyond, POS: PROPN
# Text: ,, Dependency: punct, Head Text: influence, POS: PUNCT
# Text: with, Dependency: prep, Head Text: influence, POS: ADP
# Text: Maratha, Dependency: compound, Head Text: forces, POS: PROPN
# Text: forces, Dependency: nsubj, Head Text: becoming, POS: NOUN
# Text: eventually, Dependency: advmod, Head Text: becoming, POS: ADV
# Text: becoming, Dependency: pcomp, Head Text: with, POS: VERB
# Text: a, Dependency: det, Head Text: power, POS: DET
# Text: significant, Dependency: amod, Head Text: power, POS: ADJ
# Text: power, Dependency: attr, Head Text: becoming, POS: NOUN
# Text: across, Dependency: prep, Head Text: power, POS: ADP
# Text: India, Dependency: pobj, Head Text: across, POS: PROPN
# Text: ., Dependency: punct, Head Text: began, POS: PUNCT
# Text: Shivaji, Dependency: nsubj, Head Text: passed, POS: PROPN
# Text: passed, Dependency: ROOT, Head Text: passed, POS: VERB
# Text: away, Dependency: prt, Head Text: passed, POS: ADP
# Text: on, Dependency: prep, Head Text: passed, POS: ADP
# Text: April, Dependency: pobj, Head Text: on, POS: PROPN
# Text: 3, Dependency: nummod, Head Text: April, POS: NUM
# Text: ,, Dependency: punct, Head Text: April, POS: PUNCT
# Text: 1680, Dependency: nummod, Head Text: April, POS: NUM
# Text: ,, Dependency: punct, Head Text: April, POS: PUNCT
# Text: at, Dependency: prep, Head Text: passed, POS: ADP
# Text: Raigad, Dependency: compound, Head Text: Fort, POS: PROPN
# Text: Fort, Dependency: pobj, Head Text: at, POS: PROPN
# Text: ,, Dependency: punct, Head Text: passed, POS: PUNCT
# Text: leaving, Dependency: advcl, Head Text: passed, POS: VERB
# Text: behind, Dependency: prt, Head Text: leaving, POS: ADP
# Text: a, Dependency: det, Head Text: legacy, POS: DET
# Text: powerful, Dependency: amod, Head Text: legacy, POS: ADJ
# Text: legacy, Dependency: dobj, Head Text: leaving, POS: NOUN
# Text: and, Dependency: cc, Head Text: legacy, POS: CCONJ
# Text: a, Dependency: det, Head Text: state, POS: DET
# Text: well, Dependency: advmod, Head Text: organized, POS: ADV
# Text: -, Dependency: punct, Head Text: organized, POS: PUNCT
# Text: organized, Dependency: amod, Head Text: state, POS: VERB
# Text: state, Dependency: conj, Head Text: legacy, POS: NOUN
# Text: that, Dependency: nsubj, Head Text: continued, POS: PRON
# Text: continued, Dependency: relcl, Head Text: state, POS: VERB
# Text: to, Dependency: aux, Head Text: expand, POS: PART
# Text: expand, Dependency: xcomp, Head Text: continued, POS: VERB
# Text: after, Dependency: prep, Head Text: expand, POS: ADP
# Text: his, Dependency: poss, Head Text: death, POS: PRON
# Text: death, Dependency: pobj, Head Text: after, POS: NOUN
# Text: ., Dependency: punct, Head Text: passed, POS: PUNCT
# Text: His, Dependency: poss, Head Text: life, POS: PRON
# Text: life, Dependency: nsubj, Head Text: continue, POS: NOUN
# Text: and, Dependency: cc, Head Text: life, POS: CCONJ
# Text: ideals, Dependency: conj, Head Text: life, POS: NOUN
# Text: —, Dependency: punct, Head Text: life, POS: PUNCT
# Text: valor, Dependency: appos, Head Text: life, POS: NOUN
# Text: ,, Dependency: punct, Head Text: valor, POS: PUNCT
# Text: respect, Dependency: appos, Head Text: life, POS: NOUN
# Text: for, Dependency: prep, Head Text: respect, POS: ADP
# Text: all, Dependency: det, Head Text: faiths, POS: DET
# Text: faiths, Dependency: pobj, Head Text: for, POS: NOUN
# Text: ,, Dependency: punct, Head Text: respect, POS: PUNCT
# Text: and, Dependency: cc, Head Text: respect, POS: CCONJ
# Text: self, Dependency: compound, Head Text: rule, POS: NOUN
# Text: -, Dependency: punct, Head Text: rule, POS: PUNCT
# Text: rule, Dependency: conj, Head Text: respect, POS: NOUN
# Text: —, Dependency: punct, Head Text: life, POS: PUNCT
# Text: continue, Dependency: ROOT, Head Text: continue, POS: VERB
# Text: to, Dependency: aux, Head Text: inspire, POS: PART
# Text: inspire, Dependency: xcomp, Head Text: continue, POS: VERB
# Text: millions, Dependency: dobj, Head Text: inspire, POS: NOUN
# Text: ,, Dependency: punct, Head Text: continue, POS: PUNCT
# Text: and, Dependency: cc, Head Text: continue, POS: CCONJ
# Text: his, Dependency: poss, Head Text: legacy, POS: PRON
# Text: legacy, Dependency: nsubj, Head Text: endures, POS: NOUN
# Text: endures, Dependency: conj, Head Text: continue, POS: VERB
# Text: in, Dependency: prep, Head Text: endures, POS: ADP
# Text: the, Dependency: det, Head Text: form, POS: DET
# Text: form, Dependency: pobj, Head Text: in, POS: NOUN
# Text: of, Dependency: prep, Head Text: form, POS: ADP
# Text: the, Dependency: det, Head Text: Empire, POS: DET
# Text: Maratha, Dependency: compound, Head Text: Empire, POS: PROPN
# Text: Empire, Dependency: poss, Head Text: contributions, POS: PROPN
# Text: ’s, Dependency: case, Head Text: Empire, POS: PART
# Text: contributions, Dependency: pobj, Head Text: of, POS: NOUN
# Text: to, Dependency: prep, Head Text: contributions, POS: ADP
# Text: India, Dependency: poss, Head Text: history, POS: PROPN
# Text: ’s, Dependency: case, Head Text: India, POS: PART
# Text: history, Dependency: pobj, Head Text: to, POS: NOUN
# Text: and, Dependency: cc, Head Text: history, POS: CCONJ
# Text: culture, Dependency: conj, Head Text: history, POS: NOUN
# Text: ., Dependency: punct, Head Text: endures, POS: PUNCT

# %%
from spacy import displacy

# Visualize the dependency tree for the first sentence
first_sentence = list(doc.sents)[0]
displacy.render(first_sentence, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d2eb266bd4064f0d961dd64c58aa7d39-0" class="displacy" width="6000" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Chhatrapati</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Shivaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Maharaj</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">born</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">February</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">19,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">1630,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Shivneri</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Fort</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Maharashtra,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Shahaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Bhonsle,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Maratha</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">general,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">Jijabai,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">deeply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">influenced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Shivaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">teachings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">dharma,</tspan>
#     <tspan class="displac

# %% [markdown]
# ## 10- Phrase Matching
#
# Identify occurrences of the phrase "Maratha Empire" using spaCy's PhraseMatcher.
#
# Use spaCy’s Matcher to find patterns where Shivaji Maharaj is mentioned along with actions (verbs).

# %%
import spacy
from spacy.matcher import Matcher

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Initialize the Matcher with the shared vocabulary
matcher = Matcher(nlp.vocab)

# Define a pattern for matching phrases (e.g., "Chhatrapati Shivaji Maharaj")
pattern = [{"ORTH": "Chhatrapati"}, {"ORTH": "Shivaji"}, {"ORTH": "Maharaj"}]
matcher.add("SHIVAJI_PATTERN", [pattern])

# Process the text
doc = nlp(text)

# Apply the matcher to the doc
matches = matcher(doc)

# Display matched phrases
for match_id, start, end in matches:
    matched_span = doc[start:end]
    print("Matched Phrase:", matched_span.text)
# Out:
# Matched Phrase: Chhatrapati Shivaji Maharaj

# %% [markdown]
# ## 11- Sentence Similarity
#
# Calculate the similarity between the first two sentences of the text using spaCy.
#
# Use TextBlob to compute the similarity between sentences mentioning "Shivaji" and "Mughal Empire."

# %%
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Process the text and extract first two sentences
doc = nlp(text)
sentences = list(doc.sents)
similarity_score = sentences[0].similarity(sentences[1])
print("Similarity between first two sentences:", similarity_score)
# Out:
# Similarity between first two sentences: 0.3346603512763977
# /var/folders/90/32_msyv95d93xhhstk2p072c0000gn/T/ipykernel_33673/2317023477.py:9: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Span.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity_score = sentences[0].similarity(sentences[1])

# %%
from textblob import TextBlob

# Define sentences to compare
sentence1 = "Shivaji Maharaj was a Maratha leader."
sentence2 = "The Mughal Empire opposed Shivaji Maharaj."

# Tokenize sentences and calculate word overlap
blob1 = TextBlob(sentence1)
blob2 = TextBlob(sentence2)

# Get sets of words and calculate overlap
words1 = set(blob1.words)
words2 = set(blob2.words)
overlap = len(words1.intersection(words2)) / len(words1.union(words2))

print("Word Overlap Similarity (TextBlob):", overlap)
# Out:
# Word Overlap Similarity (TextBlob): 0.2

# %% [markdown]
# ## 12- Translation
#
# Translate the first paragraph into Hindi using TextBlob.
#
# Translate the phrase "Hindavi Swarajya" into French using TextBlob.

# %%
# !pip install --upgrade textblob
# Out:
# Requirement already satisfied: textblob in /Users/anil/anaconda3/lib/python3.11/site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in /Users/anil/.local/lib/python3.11/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /Users/anil/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (8.0.4)
# Requirement already satisfied: joblib in /Users/anil/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/anil/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/anil/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (4.65.0)

# %%
# from textblob import TextBlob

# # Create a TextBlob object and translate
# blob = TextBlob(text)
# translated_text = blob.translate(from_lang="en",to="hi")
# print("Translated Text (Hindi):", translated_text)
'''
TEXTBLOG TRANSLATE HAS BEEN DEPRECATED, THEREFORE GOOGLE TRANSLATE API IS BEING USED
'''
from googletrans import Translator

translator = Translator()
translation = translator.translate(text, src='en', dest='hi')
print(translation.text)
# Out:
# छत्रपति शिवाजी महाराज का जन्म 19 फरवरी, 1630 को महाराष्ट्र में शिवनेरी किले में, एक मराठा जनरल और जिजबाई के शाहजी भोंसले से हुआ था, जिन्होंने शिवाजी को धर्म, बहादुरी और न्याय पर अपनी शिक्षाओं से गहराई से प्रभावित किया था।कम उम्र से, शिवाजी ने उल्लेखनीय नेतृत्व गुणों का प्रदर्शन किया, जिसमें वफादार अनुयायियों का एक समूह बनाया गया और सह्याद्रि पर्वत के बीहड़ इलाके में अपने सैन्य कौशल का सम्मान किया।वह ऐसे समय के दौरान बड़ा हुआ जब सम्राट औरंगजेब और डेक्कन सुल्तानाट्स के अधीन मुगल साम्राज्य नियंत्रण के लिए मर रहे थे, अक्सर स्थानीय आबादी पर अत्याचार करते थे, जिसने उन्हें गहराई से परेशान कर दिया और मराठों के लिए स्वराज्य, या स्व-नियम स्थापित करने की उनकी इच्छा को हवा दी।16 साल की उम्र तक, शिवाजी ने गुरिल्ला युद्ध की रणनीति का उपयोग करते हुए अपने पहले किले, टोर्ना पर कब्जा कर लिया था, जो बाद में उनकी सैन्य रणनीति की पहचान बन जाएगी।जैसे -जैसे उनकी विजय बढ़ी, उन्होंने स्थानीय नेताओं के साथ गठजोड़ किया, जो कि पश्चिमी भारत में एक ठोस क्षेत्रीय आधार की स्थापना करते हुए रायगद, कोंडाना और पुरंदर जैसे प्रमुख किलों को सुरक्षित करते हुए।1659 में, उन्होंने एक बहादुर और सामरिक नेता के रूप में अपनी प्रतिष्ठा को मजबूत करते हुए, बीजापुर सल्तनत के एक प्रमुख जनरल अफजल खान का सामना किया और हराया;यह जीत डेक्कन के अधिकांश पर अपना नियंत्रण स्थापित करने में महत्वपूर्ण थी।मुगल क्षेत्रों पर शिवाजी के छापे और 1666 में आगरा में औरंगज़ेब के चंगुल से भागने से उनकी किंवदंती और आगे बढ़ गई।उन्होंने महसूस किया कि एक शक्तिशाली नौसेना अपने क्षेत्रों को विदेशी आक्रमणों से बचाने के लिए महत्वपूर्ण थी, जिससे उन्हें भारत में शुरुआती संगठित नौसेना बलों में से एक विकसित करने के लिए प्रेरित किया गया, जिससे वह पुर्तगाली, ब्रिटिश और सिद्दिस बलों के खिलाफ तटीय क्षेत्रों को सुरक्षित करने की अनुमति दे।1674 में, उन्होंने औपचारिक रूप से खुद को रायगद किले में छत्रपति के रूप में ताज पहनाया, अपनी स्वतंत्रता की घोषणा की और मराठा साम्राज्य की स्थापना की, इस प्रकार भारतीय लोकाचार में निहित एक संरचित प्रशासनिक ढांचे के साथ एक स्वायत्त राज्य हिंदावी स्वराज्य की स्थापना करने वाला पहला राजा बन गया।शिवाजी की प्रशासनिक प्रणाली अत्यधिक कुशल थी, और उन्होंने अपने लोगों के कल्याण पर जोर दिया, भ्रष्टाचार को कम करने और एक उचित कर संरचना बनाने के लिए सिस्टम स्थापित किया;उनके अष्ट प्रधान (आठ मंत्रियों की परिषद) में सुचारू शासन सुनिश्चित करने के लिए वित्त, आंतरिक मामलों, विदेश नीति और सेना के लिए विभाग शामिल थे।शिवाजी ने शासन के प्रति एक प्रगतिशील दृष्टिकोण दिखाया, धार्मिक सहिष्णुता को बढ़ावा दिया और अपने साम्राज्य के भीतर विविधता का सम्मान किया, यहां तक ​​कि मुसलमानों को अपने प्रशासन में प्रमुख पदों पर नियुक्त किया और महिलाओं के उत्पीड़न पर प्रतिबंध लगा दिया और धार्मिक स्थलों को लूट लिया।महिलाओं के लिए उनका सम्मान और न्याय के लिए उनकी वकालत ने उनके लोगों के बीच विश्वास और वफादारी को प्रेरित किया, जिससे वे अपने समय के लिए एक आदर्श शासक बन गए।शिवाजी महाराज की गुरिल्ला रणनीति, जिसे "गनीनी कावा" के रूप में जाना जाता है, जो पौराणिक हो गए और उन्हें बार-बार बहुत बड़े और बेहतर-सुसज्जित सेनाओं को बाहर करने में सक्षम बनाया, जिससे उन्हें नुकसान को कम करते हुए अपने साम्राज्य का विस्तार करने की अनुमति मिली।जैसे -जैसे उनकी प्रसिद्धि बढ़ती गई, मराठा साम्राज्य ने महाराष्ट्र से परे क्षेत्रों को प्रभावित करना शुरू कर दिया, मराठा बलों के साथ अंततः पूरे भारत में एक महत्वपूर्ण शक्ति बन गई।शिवाजी का 3 अप्रैल, 1680 को रायगद किले में निधन हो गया, एक शक्तिशाली विरासत और एक सुव्यवस्थित राज्य को पीछे छोड़ दिया, जो उनकी मृत्यु के बाद विस्तार करना जारी रखा।उनका जीवन और आदर्श-मूल्य, सभी धर्मों के लिए सम्मान, और स्व-नियम-लाखों लोगों को प्रेरित करने के लिए, और उनकी विरासत भारत के इतिहास और संस्कृति में मराठा साम्राज्य के योगदान के रूप में समाप्त होती है।

# %%
# # Define the phrase
# phrase = TextBlob("Hindavi Swarajya")

# # Translate to French
# translated_phrase = phrase.translate(to="fr")
# print("Translated Phrase (French):", translated_phrase)
'''
TEXTBLOG TRANSLATE HAS BEEN DEPRECATED, THEREFORE GOOGLE TRANSLATE API IS BEING USED
'''
phrase="Hindavi Swarajya"

translator = Translator()
translation = translator.translate(phrase, src='hi', dest='fr')
print("Translated Phrase in French",translation.text)
# Out:
# Translated Phrase in French Hindavi Swarajya

# %% [markdown]
# ## 13- Keyword Extraction
#
# Extract keywords using NLTK’s frequency distribution (common nouns and verbs).
#
# Use spaCy to identify and list unique keywords from the text (filter out stop words).

# %%
from nltk import FreqDist, pos_tag, word_tokenize

# Tokenize, tag, and filter nouns and verbs
tokens = word_tokenize(text)
tagged_tokens = pos_tag(tokens)
keywords = [word for word, pos in tagged_tokens if pos.startswith('N') or pos.startswith('V')]

# Compute frequency distribution for keywords
freq_dist = FreqDist(keywords)
print("Keyword Frequency Distribution (NLTK):", freq_dist.most_common())
# Out:
# Keyword Frequency Distribution (NLTK): [('Shivaji', 9), ('Maratha', 5), ('’', 5), ('was', 4), ('Empire', 4), ('India', 4), ('Fort', 3), ('grew', 3), ('Raigad', 3), ('establishing', 3), ('forces', 3), ('s', 3), ('Chhatrapati', 2), ('Maharaj', 2), ('Maharashtra', 2), ('general', 2), ('justice', 2), ('age', 2), ('time', 2), ('Mughal', 2), ('Aurangzeb', 2), ('Deccan', 2), ('control', 2), ('establish', 2), ('Swarajya', 2), ('guerrilla', 2), ('tactics', 2), ('territories', 2), ('allowing', 2), ('becoming', 2), ('people', 2), ('governance', 2), ('empire', 2), ('women', 2), ('respect', 2), ('expand', 2), ('legacy', 2), ('born', 1), ('February', 1), ('Shivneri', 1), ('Shahaji', 1), ('Bhonsle', 1), ('Jijabai', 1), ('influenced', 1), ('teachings', 1), ('dharma', 1), ('bravery', 1), ('exhibited', 1), ('leadership', 1), ('qualities', 1), ('forming', 1), ('group', 1), ('followers', 1), ('honing', 1), ('skills', 1), ('terrain', 1), ('Sahyadri', 1), ('mountains', 1), ('Emperor', 1), ('Sultanates', 1), ('were', 1), ('vying', 1), ('oppressing', 1), ('population', 1), ('disturbed', 1), ('fueled', 1), ('desire', 1), ('self-rule', 1), ('Marathas', 1), ('had', 1), ('captured', 1), ('fort', 1), ('Torna', 1), ('using', 1), ('warfare', 1), ('become', 1), ('hallmark', 1), ('strategy', 1), ('conquests', 1), ('formed', 1), ('alliances', 1), ('leaders', 1), ('securing', 1), ('forts', 1), ('Kondana', 1), ('Purandar', 1), ('base', 1), ('faced', 1), ('defeated', 1), ('Afzal', 1), ('Khan', 1), ('Bijapur', 1), ('Sultanate', 1), ('solidifying', 1), ('reputation', 1), ('brave', 1), ('leader', 1), ('victory', 1), ('raids', 1), ('escape', 1), ('clutches', 1), ('Agra', 1), ('bolstered', 1), ('legend', 1), ('realized', 1), ('navy', 1), ('safeguard', 1), ('invasions', 1), ('leading', 1), ('develop', 1), ('organized', 1), ('secure', 1), ('areas', 1), ('Portuguese', 1), ('British', 1), ('Siddis', 1), ('crowned', 1), ('declaring', 1), ('independence', 1), ('king', 1), ('Hindavi', 1), ('kingdom', 1), ('framework', 1), ('rooted', 1), ('ethos', 1), ('system', 1), ('emphasized', 1), ('welfare', 1), ('setting', 1), ('systems', 1), ('reduce', 1), ('corruption', 1), ('create', 1), ('tax', 1), ('structure', 1), ('Ashta', 1), ('Pradhan', 1), ('Council', 1), ('Eight', 1), ('Ministers', 1), ('included', 1), ('departments', 1), ('finance', 1), ('affairs', 1), ('policy', 1), ('ensure', 1), ('showed', 1), ('approach', 1), ('towards', 1), ('promoting', 1), ('tolerance', 1), ('respecting', 1), ('diversity', 1), ('appointing', 1), ('Muslims', 1), ('key', 1), ('positions', 1), ('administration', 1), ('banning', 1), ('harassment', 1), ('looting', 1), ('sites', 1), ('advocacy', 1), ('inspired', 1), ('trust', 1), ('loyalty', 1), ('making', 1), ('ideal', 1), ('ruler', 1), ('known', 1), ('Ganimi', 1), ('Kava', 1), ('”', 1), ('became', 1), ('enabled', 1), ('outmaneuver', 1), ('armies', 1), ('minimizing', 1), ('losses', 1), ('fame', 1), ('began', 1), ('influence', 1), ('regions', 1), ('power', 1), ('passed', 1), ('April', 1), ('leaving', 1), ('state', 1), ('continued', 1), ('death', 1), ('life', 1), ('ideals—valor', 1), ('faiths', 1), ('self-rule—continue', 1), ('inspire', 1), ('millions', 1), ('endures', 1), ('form', 1), ('contributions', 1), ('history', 1), ('culture', 1)]

# %%
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Process the text
doc = nlp(text)

# Filter keywords, excluding stop words
keywords_spacy = [token.text for token in doc if not token.is_stop and (token.pos_ == "NOUN" or token.pos_ == "VERB")]
unique_keywords = set(keywords_spacy)
print("Unique Keywords (spaCy):", unique_keywords)
# Out:
# Unique Keywords (spaCy): {'looting', 'women', 'conquests', 'kingdom', 'inspire', 'strategy', 'teachings', 'promoting', 'losses', 'tax', 'oppressing', 'born', 'safeguard', 'positions', 'respect', 'leader', 'ruler', 'reputation', 'followers', 'banning', 'appointing', 'exhibited', 'affairs', 'tactics', 'organized', 'structure', 'departments', 'history', 'solidifying', 'making', 'framework', 'create', 'declaring', 'administration', 'forces', 'millions', 'advocacy', 'diversity', 'faced', 'passed', 'hallmark', 'ethos', 'military', 'formed', 'continue', 'empire', 'minimizing', 'qualities', 'skills', 'corruption', 'expand', 'population', 'victory', 'setting', 'securing', 'tolerance', 'harassment', 'continued', 'reduce', 'secure', 'captured', 'realized', 'establishing', 'sites', 'welfare', 'areas', 'influenced', 'governance', 'trust', 'began', 'leaving', 'rooted', 'legacy', 'dharma', 'desire', 'honing', 'rule', 'guerrilla', 'invasions', 'policy', 'death', 'form', 'leaders', 'valor', 'clutches', 'territories', 'age', 'group', 'general', 'warfare', 'justice', 'ensure', 'base', 'contributions', 'endures', 'faiths', 'defeated', 'raids', 'included', 'fort', 'loyalty', 'self', 'time', 'forming', 'approach', 'leadership', 'vying', 'outmaneuver', 'regions', 'fueled', 'influence', 'state', 'life', 'terrain', 'leading', 'emphasized', 'independence', 'forts', 'fame', 'culture', 'power', 'respecting', 'develop', 'king', 'grew', 'control', 'people', 'bolstered', 'enabled', 'finance', 'mountains', 'systems', 'known', 'armies', 'disturbed', 'bravery', 'crowned', 'establish', 'allowing', 'ideals', 'escape', 'alliances', 'legend', 'system', 'showed', 'inspired', 'navy', 'equipped'}

# %% [markdown]
# ## 14- Coreference Resolution
#
# Use spaCy's neuralcoref extension to resolve pronouns in the text.
#
# Identify any instances where pronouns can be replaced with entity names for better clarity.

# %%
import spacy
import neuralcoref

# Load spaCy's English model and add neuralcoref to it
nlp = spacy.load("en_core_web_sm")
neuralcoref.add_to_pipe(nlp)

# Process text with coreference resolution
doc = nlp(text)
resolved_text = doc._.coref_resolved
print("Text with Coreference Resolution:", resolved_text)

# %% [markdown]
# ## 15- Sentiment Polarity Distribution
#
# Calculate and plot the sentiment polarity distribution for each sentence in the text using TextBlob.
#
# Identify and display the most positive and most negative sentences based on sentiment scores.

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt

# Create a TextBlob object
blob = TextBlob(text)

# Calculate polarity for each sentence
polarities = [sentence.sentiment.polarity for sentence in blob.sentences]

# Plot polarity distribution
plt.hist(polarities, bins=10, edgecolor='black')
plt.title("Sentiment Polarity Distribution")
plt.xlabel("Polarity")
plt.ylabel("Frequency")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Identify sentences with the highest and lowest polarity
most_positive_sentence = max(blob.sentences, key=lambda sentence: sentence.sentiment.polarity)
most_negative_sentence = min(blob.sentences, key=lambda sentence: sentence.sentiment.polarity)

print("Most Positive Sentence:", most_positive_sentence)
print("Most Negative Sentence:", most_negative_sentence)
# Out:
# Most Positive Sentence: His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time.
# Most Negative Sentence: As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.

# %% [markdown]
# ## 16- Extract Dates and Events
#
# Identify all dates mentioned in the text using spaCy.
#
# Use regex to find sentences related to events happening in specific years (e.g., 1674 or 1680).

# %%
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Process text and identify dates
doc = nlp(text)
dates = [ent.text for ent in doc.ents if ent.label_ == "DATE"]
print("Dates Mentioned:", dates)
# Out:
# Dates Mentioned: ['February 19, 1630', 'an early age', 'the age of 16', '1659', '1666', '1674', 'April 3, 1680']

# %%
import re
from nltk.tokenize import sent_tokenize

# Define target years and tokenize text into sentences
target_years = ["1674", "1680"]
sentences = sent_tokenize(text)

# Find sentences mentioning target years
event_sentences = [sentence for sentence in sentences if any(year in sentence for year in target_years)]
print("Event-related Sentences:", event_sentences)
# Out:
# Event-related Sentences: ['In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.', 'Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.']

# %% [markdown]
# ## 17- Synonyms and Antonyms
#
# Use TextBlob's WordNet to find synonyms for "bravery," "justice," and "valor."
#
# Find antonyms of "oppression" and "invasion" using NLTK’s WordNet.

# %%
from textblob import Word

# Define words
words = ["bravery", "justice", "valor"]

# Find synonyms
for word_str in words:
    word = Word(word_str)
    synonyms = set()
    for synset in word.synsets:
        for lemma in synset.lemmas():
            synonyms.add(lemma.name())
    print(f"Synonyms for '{word_str}':", synonyms)
# Out:
# Synonyms for 'bravery': {'braveness', 'courageousness', 'bravery', 'courage', 'fearlessness'}
# Synonyms for 'justice': {'justness', 'jurist', 'judge', 'Justice_Department', 'justice', 'Department_of_Justice', 'Justice', 'DoJ'}
# Synonyms for 'valor': {'valorousness', 'valiancy', 'valiance', 'valour', 'valor', 'heroism', 'gallantry'}

# %%
from nltk.corpus import wordnet

# Define words
words = ["oppression", "invasion"]

# Find antonyms
for word in words:
    antonyms = set()
    for synset in wordnet.synsets(word):
        for lemma in synset.lemmas():
            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())
    print(f"Antonyms for '{word}':", antonyms)
# Out:
# Antonyms for 'oppression': set()
# Antonyms for 'invasion': set()

# %% [markdown]
# ## 18- Spelling Correction
#
# Introduce 5 spelling errors in the text and use TextBlob to correct them.
#
# Identify words with potential spelling errors using TextBlob.

# %%
from textblob import TextBlob

# Define the text with intentional spelling errors
text_with_errors = """
Chhatrapati Shivaji Maharaj ws born on Febuary 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhosle, 
a Maratha genral, and Jijabai, who deply influnced Shivaji wth her teachings on dharma, bravery, and justice.
"""

# Create a TextBlob object and apply spelling correction
blob = TextBlob(text_with_errors)
corrected_text = blob.correct()
print("Corrected Text:", corrected_text)
# Out:
# Corrected Text:
# Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Sort in Maharashtra, to Shahaji Those,
# a Martha general, and Jijabai, who reply influenced Shivaji with her teachings on harm, bravery, and justice.

# %% [markdown]
# ## 19- Extract Subject-Verb-Object Triples
#
# Use spaCy to extract subject-verb-object triples from the sentences.
#
# Identify and list sentences where "Shivaji" is the subject and a verb follows, using dependency parsing.

# %%
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Process the text and extract SVO triples
doc = nlp(text)
svo_triples = []
for token in doc:
    if token.dep_ == "nsubj" and token.head.pos_ == "VERB":
        subject = token
        verb = token.head
        for child in verb.children:
            if child.dep_ == "dobj":
                obj = child
                svo_triples.append((subject, verb, obj))

print("Extracted SVO Triples:", [(s.text, v.text, o.text) for s, v, o in svo_triples])
# Out:
# Extracted SVO Triples: [('who', 'influenced', 'Shivaji'), ('Shivaji', 'exhibited', 'qualities'), ('which', 'disturbed', 'him'), ('Shivaji', 'captured', 'fort'), ('he', 'formed', 'alliances'), ('raids', 'bolstered', 'legend'), ('him', 'secure', 'areas'), ('he', 'crowned', 'himself'), ('he', 'emphasized', 'welfare'), ('Pradhan', 'included', 'departments'), ('Shivaji', 'showed', 'approach'), ('respect', 'inspired', 'trust'), ('him', 'expand', 'empire')]

# %%
# Find sentences where "Shivaji" is the subject
shivaji_sentences = []
for sent in doc.sents:
    for token in sent:
        if token.text == "Shivaji" and token.dep_ == "nsubj":
            shivaji_sentences.append(sent.text)
            break

print("Sentences Where 'Shivaji' is the Subject:", shivaji_sentences)
# Out:
# Sentences Where 'Shivaji' is the Subject: ['From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.', 'By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy.', 'Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites.', 'Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.']

# %% [markdown]
# ## 20- Create a Summary
#
# Summarize the text using TextBlob by extracting key sentences.
#
# Generate a summary using NLTK’s summarize function on cleaned text.

# %%
from textblob import TextBlob

# Create a TextBlob object
blob = TextBlob(text)

# Extract sentences with higher sentiment polarity as a summary
summary_sentences = [sentence for sentence in blob.sentences if sentence.sentiment.polarity > 0]
summary_text = " ".join([str(sentence) for sentence in summary_sentences])
print("Summary (TextBlob):", summary_text)
# Out:
# Summary (TextBlob): Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India.

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import nltk


# Tokenize sentences and words
sentences = sent_tokenize(text)
words = word_tokenize(text)

# Calculate word frequencies, ignoring stop words
stop_words = set(stopwords.words('english'))
filtered_words = [word.lower() for word in words if word.isalnum() and word.lower() not in stop_words]
freq_dist = FreqDist(filtered_words)

# Score sentences by summing word frequencies
sentence_scores = {sentence: sum(freq_dist[word.lower()] for word in word_tokenize(sentence) if word.lower() in freq_dist) for sentence in sentences}

# Select top sentences for summary
sorted_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=True)
summary_nltk = " ".join(sorted_sentences[:2])  # Adjust number of sentences as needed
print("Summary (NLTK):", summary_nltk)
# Out:
# Summary (NLTK): Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.
